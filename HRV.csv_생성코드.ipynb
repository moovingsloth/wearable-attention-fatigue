# %%
import os
import pandas as pd
import numpy as np
from scipy.signal import welch

def compute_ln_lf_hf(rri_series: pd.Series, fs: float = 2.0):
    """Welch PSD로 HRV 계산 후 ln(LF), ln(HF) 리턴"""
    if rri_series.isnull().any():
        rri_series = rri_series.dropna()

    if len(rri_series) < fs * 30:  # 최소 30초 이상 필요
        return np.nan, np.nan

    freqs, psd = welch(rri_series.values, fs=fs, nperseg=min(256, len(rri_series)))

    lf_band = (freqs >= 0.0033) & (freqs < 0.04)
    hf_band = (freqs >= 0.15) & (freqs <= 0.4)

    lf_power = np.trapz(psd[lf_band], freqs[lf_band])
    hf_power = np.trapz(psd[hf_band], freqs[hf_band])

    ln_lf = np.log(lf_power) if lf_power > 0 else np.nan
    ln_hf = np.log(hf_power) if hf_power > 0 else np.nan
    return ln_lf, ln_hf

def process_participant_rri_to_hrv(sensor_base_path: str, pid: str):
    """RRI → HRV 변환하여 HRV.csv 저장"""
    rri_path = os.path.join(sensor_base_path, pid, 'RRI.csv')
    hrv_path = os.path.join(sensor_base_path, pid, 'HRV.csv')

    if not os.path.exists(rri_path):
        print(f"[!] {pid} RRI.csv not found.")
        return

    try:
        # 1. RRI 데이터 불러오기
        rri_df = pd.read_csv(rri_path)
        rri_df['timestamp'] = pd.to_datetime(rri_df['timestamp'], unit='ms', utc=True)
        rri_df.set_index('timestamp', inplace=True)
        rri_df = rri_df.sort_index()

        # 2. 500ms 간격 리샘플링 + 선형 보간 (양방향)
        resampled = (
            rri_df['interval']
            .resample('500ms')
            .mean()
            .interpolate(method='linear', limit_direction='both')
        )

        # 3. 5분 단위 슬라이딩 윈도우로 HRV 계산
        features = []
        for start in pd.date_range(resampled.index[0], resampled.index[-1], freq='5min'):
            window = resampled[start : start + pd.Timedelta('5min')]
            ln_lf, ln_hf = compute_ln_lf_hf(window)
            features.append({
                'timestamp': start,
                'ln_lf': ln_lf,
                'ln_hf': ln_hf
            })

        # 4. CSV 저장
        hrv_df = pd.DataFrame(features).dropna()
        hrv_df.to_csv(hrv_path, index=False)
        print(f"[✓] {pid}: HRV.csv saved. ({len(hrv_df)} rows)")

    except Exception as e:
        print(f"[!] Error in {pid}: {e}")

def process_all_participants(sensor_base_path: str, pids=range(1, 81)):
    """P01~P80 전체 참가자 처리"""
    for i in pids:
        pid = f'P{i:02d}'
        process_participant_rri_to_hrv(sensor_base_path, pid)

# ✅ 실행 예시
sensor_path = './data/Sensor'  # 실제 경로에 맞게 조정
process_all_participants(sensor_path)
# Out:
# [✓] P01: HRV.csv saved. (1869 rows)
# [✓] P02: HRV.csv saved. (1867 rows)
# [✓] P03: HRV.csv saved. (1841 rows)
# [✓] P04: HRV.csv saved. (1811 rows)
# [✓] P05: HRV.csv saved. (1901 rows)
# [✓] P06: HRV.csv saved. (1856 rows)
# [✓] P07: HRV.csv saved. (1860 rows)
# [✓] P08: HRV.csv saved. (1787 rows)
# [✓] P09: HRV.csv saved. (1886 rows)
# [✓] P10: HRV.csv saved. (1864 rows)
# [✓] P11: HRV.csv saved. (1769 rows)
# [✓] P12: HRV.csv saved. (1856 rows)
# [✓] P13: HRV.csv saved. (1874 rows)
# [✓] P14: HRV.csv saved. (1895 rows)
# [✓] P15: HRV.csv saved. (1872 rows)
# [✓] P16: HRV.csv saved. (1861 rows)
# [✓] P17: HRV.csv saved. (1717 rows)
# [✓] P18: HRV.csv saved. (1780 rows)
# [✓] P19: HRV.csv saved. (1851 rows)
# [✓] P20: HRV.csv saved. (1873 rows)
# [✓] P21: HRV.csv saved. (1862 rows)
# [✓] P22: HRV.csv saved. (473 rows)
# [✓] P23: HRV.csv saved. (1863 rows)
# [✓] P24: HRV.csv saved. (1864 rows)
# [✓] P25: HRV.csv saved. (1141 rows)
# [✓] P26: HRV.csv saved. (1874 rows)
# [!] P27 RRI.csv not found.
# [✓] P28: HRV.csv saved. (1881 rows)
# [✓] P29: HRV.csv saved. (1820 rows)
# [✓] P30: HRV.csv saved. (1793 rows)
# [✓] P31: HRV.csv saved. (1840 rows)
# [✓] P32: HRV.csv saved. (1877 rows)
# [✓] P33: HRV.csv saved. (1904 rows)
# [✓] P34: HRV.csv saved. (1555 rows)
# [✓] P35: HRV.csv saved. (1878 rows)
# [✓] P36: HRV.csv saved. (1858 rows)
# [✓] P37: HRV.csv saved. (1628 rows)
# [✓] P38: HRV.csv saved. (1872 rows)
# [✓] P39: HRV.csv saved. (1892 rows)
# [✓] P40: HRV.csv saved. (1923 rows)
# [✓] P41: HRV.csv saved. (1636 rows)
# [✓] P42: HRV.csv saved. (1865 rows)
# [✓] P43: HRV.csv saved. (1288 rows)
# [✓] P44: HRV.csv saved. (1811 rows)
# [✓] P45: HRV.csv saved. (1806 rows)
# [✓] P46: HRV.csv saved. (1802 rows)
# [✓] P47: HRV.csv saved. (1862 rows)
# [✓] P48: HRV.csv saved. (1869 rows)
# [✓] P49: HRV.csv saved. (1861 rows)
# [✓] P50: HRV.csv saved. (1862 rows)
# [✓] P51: HRV.csv saved. (1757 rows)
# [✓] P52: HRV.csv saved. (1926 rows)
# [✓] P53: HRV.csv saved. (1567 rows)
# [✓] P54: HRV.csv saved. (1133 rows)
# [✓] P55: HRV.csv saved. (1847 rows)
# [✓] P56: HRV.csv saved. (1533 rows)
# [✓] P57: HRV.csv saved. (1770 rows)
# [✓] P58: HRV.csv saved. (1832 rows)
# [!] P59 RRI.csv not found.
# [✓] P60: HRV.csv saved. (1870 rows)
# [✓] P61: HRV.csv saved. (1877 rows)
# [✓] P62: HRV.csv saved. (1852 rows)
# [✓] P63: HRV.csv saved. (1828 rows)
# [✓] P64: HRV.csv saved. (1865 rows)
# [!] P65 RRI.csv not found.
# [✓] P66: HRV.csv saved. (1854 rows)
# [✓] P67: HRV.csv saved. (1846 rows)
# [✓] P68: HRV.csv saved. (1883 rows)
# [✓] P69: HRV.csv saved. (1873 rows)
# [✓] P70: HRV.csv saved. (1883 rows)
# [✓] P71: HRV.csv saved. (1872 rows)
# [✓] P72: HRV.csv saved. (1856 rows)
# [✓] P73: HRV.csv saved. (1820 rows)
# [✓] P74: HRV.csv saved. (1530 rows)
# [✓] P75: HRV.csv saved. (1875 rows)
# [✓] P76: HRV.csv saved. (1931 rows)
# [✓] P77: HRV.csv saved. (1815 rows)
# [✓] P78: HRV.csv saved. (1884 rows)
# [✓] P79: HRV.csv saved. (1850 rows)
# [✓] P80: HRV.csv saved. (1592 rows)

# %%
import os

def delete_hrv_files(sensor_base_path: str, pids=range(1, 81)):
    """P01~P80 폴더 내 HRV.csv 파일 삭제"""
    for i in pids:
        pid = f'P{i:02d}'
        hrv_path = os.path.join(sensor_base_path, pid, 'HRV.csv')
        
        if os.path.exists(hrv_path):
            try:
                os.remove(hrv_path)
                print(f"[🗑] {pid}: HRV.csv deleted.")
            except Exception as e:
                print(f"[!] Failed to delete {pid}: {e}")
        else:
            print(f"[ ] {pid}: HRV.csv not found. Skipped.")

# ✅ 실행
sensor_path = './data/Sensor'  # 경로를 실제 사용 중인 위치로 수정 가능
delete_hrv_files(sensor_path)
# Out:
# [🗑] P01: HRV.csv deleted.
# [ ] P02: HRV.csv not found. Skipped.
# [ ] P03: HRV.csv not found. Skipped.
# [ ] P04: HRV.csv not found. Skipped.
# [ ] P05: HRV.csv not found. Skipped.
# [ ] P06: HRV.csv not found. Skipped.
# [ ] P07: HRV.csv not found. Skipped.
# [ ] P08: HRV.csv not found. Skipped.
# [ ] P09: HRV.csv not found. Skipped.
# [ ] P10: HRV.csv not found. Skipped.
# [ ] P11: HRV.csv not found. Skipped.
# [ ] P12: HRV.csv not found. Skipped.
# [ ] P13: HRV.csv not found. Skipped.
# [ ] P14: HRV.csv not found. Skipped.
# [ ] P15: HRV.csv not found. Skipped.
# [ ] P16: HRV.csv not found. Skipped.
# [ ] P17: HRV.csv not found. Skipped.
# [ ] P18: HRV.csv not found. Skipped.
# [ ] P19: HRV.csv not found. Skipped.
# [ ] P20: HRV.csv not found. Skipped.
# [ ] P21: HRV.csv not found. Skipped.
# [ ] P22: HRV.csv not found. Skipped.
# [ ] P23: HRV.csv not found. Skipped.
# [ ] P24: HRV.csv not found. Skipped.
# [ ] P25: HRV.csv not found. Skipped.
# [ ] P26: HRV.csv not found. Skipped.
# [ ] P27: HRV.csv not found. Skipped.
# [ ] P28: HRV.csv not found. Skipped.
# [ ] P29: HRV.csv not found. Skipped.
# [ ] P30: HRV.csv not found. Skipped.
# [ ] P31: HRV.csv not found. Skipped.
# [ ] P32: HRV.csv not found. Skipped.
# [ ] P33: HRV.csv not found. Skipped.
# [ ] P34: HRV.csv not found. Skipped.
# [ ] P35: HRV.csv not found. Skipped.
# [ ] P36: HRV.csv not found. Skipped.
# [ ] P37: HRV.csv not found. Skipped.
# [ ] P38: HRV.csv not found. Skipped.
# [ ] P39: HRV.csv not found. Skipped.
# [ ] P40: HRV.csv not found. Skipped.
# [ ] P41: HRV.csv not found. Skipped.
# [ ] P42: HRV.csv not found. Skipped.
# [ ] P43: HRV.csv not found. Skipped.
# [ ] P44: HRV.csv not found. Skipped.
# [ ] P45: HRV.csv not found. Skipped.
# [ ] P46: HRV.csv not found. Skipped.
# [ ] P47: HRV.csv not found. Skipped.
# [ ] P48: HRV.csv not found. Skipped.
# [ ] P49: HRV.csv not found. Skipped.
# [ ] P50: HRV.csv not found. Skipped.
# [ ] P51: HRV.csv not found. Skipped.
# [ ] P52: HRV.csv not found. Skipped.
# [ ] P53: HRV.csv not found. Skipped.
# [ ] P54: HRV.csv not found. Skipped.
# [ ] P55: HRV.csv not found. Skipped.
# [ ] P56: HRV.csv not found. Skipped.
# [ ] P57: HRV.csv not found. Skipped.
# [ ] P58: HRV.csv not found. Skipped.
# [ ] P59: HRV.csv not found. Skipped.
# [ ] P60: HRV.csv not found. Skipped.
# [ ] P61: HRV.csv not found. Skipped.
# [ ] P62: HRV.csv not found. Skipped.
# [ ] P63: HRV.csv not found. Skipped.
# [ ] P64: HRV.csv not found. Skipped.
# [ ] P65: HRV.csv not found. Skipped.
# [ ] P66: HRV.csv not found. Skipped.
# [ ] P67: HRV.csv not found. Skipped.
# [ ] P68: HRV.csv not found. Skipped.
# [ ] P69: HRV.csv not found. Skipped.
# [ ] P70: HRV.csv not found. Skipped.
# [ ] P71: HRV.csv not found. Skipped.
# [ ] P72: HRV.csv not found. Skipped.
# [ ] P73: HRV.csv not found. Skipped.
# [ ] P74: HRV.csv not found. Skipped.
# [ ] P75: HRV.csv not found. Skipped.
# [ ] P76: HRV.csv not found. Skipped.
# [ ] P77: HRV.csv not found. Skipped.
# [ ] P78: HRV.csv not found. Skipped.
# [ ] P79: HRV.csv not found. Skipped.
# [ ] P80: HRV.csv not found. Skipped.

# %%
import os
import pandas as pd
import numpy as np
from scipy.signal import welch

def compute_ln_lf_hf(rri_series: pd.Series, fs: float = 2.0):
    """Welch PSD로 HRV 계산 후 ln(LF), ln(HF) 리턴 (신뢰성 검사 포함)"""
    rri_series = rri_series.dropna()

    if len(rri_series) < fs * 30:
        return np.nan, np.nan
    if rri_series.std() < 1.0:
        return np.nan, np.nan

    freqs, psd = welch(rri_series.values, fs=fs, nperseg=min(256, len(rri_series)))

    lf_band = (freqs >= 0.0033) & (freqs < 0.04)
    hf_band = (freqs >= 0.15) & (freqs <= 0.4)

    lf_power = np.trapz(psd[lf_band], freqs[lf_band])
    hf_power = np.trapz(psd[hf_band], freqs[hf_band])

    if lf_power < 1e-6 or hf_power < 1e-6:
        return np.nan, np.nan

    ln_lf = np.log(lf_power)
    ln_hf = np.log(hf_power)
    return ln_lf, ln_hf


def process_participant_rri_to_hrv(sensor_base_path: str, pid: str):
    rri_path = os.path.join(sensor_base_path, pid, 'RRI.csv')
    hrv_path = os.path.join(sensor_base_path, pid, 'HRV.csv')

    if not os.path.exists(rri_path):
        print(f"[!] {pid} RRI.csv not found.")
        return

    try:
        rri_df = pd.read_csv(rri_path)
        rri_df['timestamp'] = pd.to_datetime(rri_df['timestamp'], unit='ms', utc=True)
        rri_df.set_index('timestamp', inplace=True)
        rri_df = rri_df.sort_index()

        resampled = (
            rri_df['interval']
            .resample('500ms')
            .mean()
            .interpolate(method='linear', limit_direction='both')
        )

        features = []
        for start in pd.date_range(resampled.index[0], resampled.index[-1], freq='5min'):
            window = resampled[start : start + pd.Timedelta('5min')]
            ln_lf, ln_hf = compute_ln_lf_hf(window)
            if not np.isnan(ln_lf) and not np.isnan(ln_hf):
                features.append({
                    'timestamp': start,
                    'ln_lf': ln_lf,
                    'ln_hf': ln_hf
                })

        hrv_df = pd.DataFrame(features)

        # ✅ timestamp를 epoch milliseconds로 변환
        hrv_df['timestamp'] = hrv_df['timestamp'].astype(np.int64) // 10**6

        hrv_df.to_csv(hrv_path, index=False)
        print(f"[✓] {pid}: HRV.csv saved. ({len(hrv_df)} valid rows)")

    except Exception as e:
        print(f"[!] Error in {pid}: {e}")


def process_all_participants(sensor_base_path: str, pids=range(1, 81)):
    for i in pids:
        pid = f'P{i:02d}'
        process_participant_rri_to_hrv(sensor_base_path, pid)


# ✅ 실행
sensor_path = './data/Sensor'
process_all_participants(sensor_path)
# Out:
# [✓] P01: HRV.csv saved. (717 valid rows)
# [✓] P02: HRV.csv saved. (786 valid rows)
# [✓] P03: HRV.csv saved. (385 valid rows)
# [✓] P04: HRV.csv saved. (800 valid rows)
# [✓] P05: HRV.csv saved. (716 valid rows)
# [✓] P06: HRV.csv saved. (651 valid rows)
# [✓] P07: HRV.csv saved. (721 valid rows)
# [✓] P08: HRV.csv saved. (441 valid rows)
# [✓] P09: HRV.csv saved. (807 valid rows)
# [✓] P10: HRV.csv saved. (1048 valid rows)
# [✓] P11: HRV.csv saved. (627 valid rows)
# [✓] P12: HRV.csv saved. (827 valid rows)
# [✓] P13: HRV.csv saved. (730 valid rows)
# [✓] P14: HRV.csv saved. (745 valid rows)
# [✓] P15: HRV.csv saved. (983 valid rows)
# [✓] P16: HRV.csv saved. (1103 valid rows)
# [✓] P17: HRV.csv saved. (511 valid rows)
# [✓] P18: HRV.csv saved. (629 valid rows)
# [✓] P19: HRV.csv saved. (456 valid rows)
# [✓] P20: HRV.csv saved. (954 valid rows)
# [✓] P21: HRV.csv saved. (973 valid rows)
# [✓] P22: HRV.csv saved. (216 valid rows)
# [✓] P23: HRV.csv saved. (891 valid rows)
# [✓] P24: HRV.csv saved. (727 valid rows)
# [✓] P25: HRV.csv saved. (494 valid rows)
# [✓] P26: HRV.csv saved. (958 valid rows)
# [!] P27 RRI.csv not found.
# [✓] P28: HRV.csv saved. (770 valid rows)
# [✓] P29: HRV.csv saved. (830 valid rows)
# [✓] P30: HRV.csv saved. (822 valid rows)
# [✓] P31: HRV.csv saved. (708 valid rows)
# [✓] P32: HRV.csv saved. (882 valid rows)
# [✓] P33: HRV.csv saved. (667 valid rows)
# [✓] P34: HRV.csv saved. (433 valid rows)
# [✓] P35: HRV.csv saved. (798 valid rows)
# [✓] P36: HRV.csv saved. (644 valid rows)
# [✓] P37: HRV.csv saved. (679 valid rows)
# [✓] P38: HRV.csv saved. (783 valid rows)
# [✓] P39: HRV.csv saved. (1023 valid rows)
# [✓] P40: HRV.csv saved. (727 valid rows)
# [✓] P41: HRV.csv saved. (674 valid rows)
# [✓] P42: HRV.csv saved. (1047 valid rows)
# [✓] P43: HRV.csv saved. (462 valid rows)
# [✓] P44: HRV.csv saved. (432 valid rows)
# [✓] P45: HRV.csv saved. (311 valid rows)
# [✓] P46: HRV.csv saved. (819 valid rows)
# [✓] P47: HRV.csv saved. (912 valid rows)
# [✓] P48: HRV.csv saved. (798 valid rows)
# [✓] P49: HRV.csv saved. (785 valid rows)
# [✓] P50: HRV.csv saved. (987 valid rows)
# [✓] P51: HRV.csv saved. (822 valid rows)
# [✓] P52: HRV.csv saved. (703 valid rows)
# [✓] P53: HRV.csv saved. (480 valid rows)
# [✓] P54: HRV.csv saved. (217 valid rows)
# [✓] P55: HRV.csv saved. (657 valid rows)
# [✓] P56: HRV.csv saved. (469 valid rows)
# [✓] P57: HRV.csv saved. (709 valid rows)
# [✓] P58: HRV.csv saved. (447 valid rows)
# [!] P59 RRI.csv not found.
# [✓] P60: HRV.csv saved. (556 valid rows)
# [✓] P61: HRV.csv saved. (827 valid rows)
# [✓] P62: HRV.csv saved. (928 valid rows)
# [✓] P63: HRV.csv saved. (823 valid rows)
# [✓] P64: HRV.csv saved. (927 valid rows)
# [!] P65 RRI.csv not found.
# [✓] P66: HRV.csv saved. (1039 valid rows)
# [✓] P67: HRV.csv saved. (671 valid rows)
# [✓] P68: HRV.csv saved. (919 valid rows)
# [✓] P69: HRV.csv saved. (802 valid rows)
# [✓] P70: HRV.csv saved. (872 valid rows)
# [✓] P71: HRV.csv saved. (1002 valid rows)
# [✓] P72: HRV.csv saved. (696 valid rows)
# [✓] P73: HRV.csv saved. (644 valid rows)
# [✓] P74: HRV.csv saved. (259 valid rows)
# [✓] P75: HRV.csv saved. (1047 valid rows)
# [✓] P76: HRV.csv saved. (942 valid rows)
# [✓] P77: HRV.csv saved. (618 valid rows)
# [✓] P78: HRV.csv saved. (416 valid rows)
# [✓] P79: HRV.csv saved. (742 valid rows)
# [✓] P80: HRV.csv saved. (541 valid rows)
