# %% [markdown]
# # Settings

# %% [markdown]
# ## Constant

# %%
import pytz
import os


DEFAULT_TZ = pytz.FixedOffset(540)  # GMT+09:00; Asia/Seoul

PATH_DATA = './data'
PATH_ESM = os.path.join(PATH_DATA, 'EsmResponse.csv')
PATH_PARTICIPANT = os.path.join(PATH_DATA, 'UserInfo.csv')
PATH_SENSOR = os.path.join(PATH_DATA, 'Sensor')

PATH_INTERMEDIATE = './intermediate'

DATA_TYPES = {
#    'EDA': 'EDA',
#    'HR': 'HRT',
    'RRI': 'RRI',
#    'SkinTemperature': 'SKT',
}

os.makedirs(PATH_INTERMEDIATE, exist_ok=True)

# %% [markdown]
# ## Utility Functions

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import cloudpickle
import ray
from datetime import datetime
from contextlib import contextmanager
import warnings
import time


def load(path: str):
    with open(path, mode='rb') as f:
        return cloudpickle.load(f)
    
def dump(obj, path: str):
    with open(path, mode='wb') as f:
        cloudpickle.dump(obj, f)
    
def log(msg: any):
    print('[{}] {}'.format(datetime.now().strftime('%y-%m-%d %H:%M:%S'), msg))

def summary(x):
    x = np.asarray(x)
    with warnings.catch_warnings():
        warnings.simplefilter('ignore')

        n = len(x)
        # Here, uppercase np.dtype.kind corresponds to non-numeric data.
        # Also, we view the boolean data as dichotomous categorical data.
        if x.dtype.kind.isupper() or x.dtype.kind == 'b': 
            cnt = pd.Series(x).value_counts(dropna=False)
            card = len(cnt)
            cnt = cnt[:20]                
            cnt_str = ', '.join([f'{u}:{c}' for u, c in zip(cnt.index, cnt)])
            if card > 30:
                cnt_str = f'{cnt_str}, ...'
            return {
                'n': n,
                'cardinality': card,
                'value_count': cnt_str
            }
        else: 
            x_nan = x[np.isnan(x)]
            x_norm = x[~np.isnan(x)]
            
            tot = np.sum(x_norm)
            m = np.mean(x_norm)
            me = np.median(x_norm)
            s = np.std(x_norm, ddof=1)
            l, u = np.min(x_norm), np.max(x)
            conf_l, conf_u = st.t.interval(0.95, len(x_norm) - 1, loc=m, scale=st.sem(x_norm))
            n_nan = len(x_nan)
            
            return {
                'n': n,
                'sum': tot,
                'mean': m,
                'SD': s,
                'med': me,
                'range': (l, u),
                'conf.': (conf_l, conf_u),
                'nan_count': n_nan
            }


@contextmanager
def on_ray(*args, **kwargs):
    try:
        if ray.is_initialized():
            ray.shutdown()
        ray.init(*args, **kwargs)
        yield None
    finally:
        ray.shutdown()

# %% [markdown]
# ## Settings for R

# %%
# %load_ext rpy2.ipython

# %%
# %%R

# library(tidyverse)
# library(ggforce)
# library(ggpubr)
# library(showtext)
# library(rmcorr)
# library(patchwork)

# # font_add_google(
# #     name='Source Serif Pro',
# #     family='ssp',
# #     db_cache=FALSE
# # )

# showtext_auto()

# THEME_DEFAULT <- theme_bw(
#     base_size=10,
#     base_family='ssp',
# ) + theme(
#         axis.title.x=element_text(colour='grey20', size=10, face='bold'),
#         axis.title.y=element_text(colour='grey20', size=10, face='bold'),
#         axis.text.x=element_text(colour='grey20', size=10),
#         axis.text.y=element_text(colour='grey20', size=10),
#         strip.text.x=element_text(colour='grey20', size=10, face='bold'),
#         strip.text.y=element_text(colour='grey20', size=10, face='bold'),
#         legend.background=element_blank(),
#         legend.title=element_text(colour='grey20', size=10, face='bold'),
#         legend.text=element_text(colour='grey20', size=10),
#         legend.position='top',
#         legend.box.spacing= unit(0, 'cm'),
#         plot.subtitle=element_text(colour='grey20', size=10, hjust=.5),
#     )

# %% [markdown]
# # Dataset Overview

# %% [markdown]
# ## Participants

# %%
import pandas as pd
import os


PARTICIPANTS = pd.read_csv(PATH_PARTICIPANT).set_index('pcode').assign(
    particpationStartDateTime=lambda x: pd.to_datetime(
        x['participationStartDate'], format='%Y-%m-%d'
    ).dt.tz_localize(DEFAULT_TZ)
)
PARTICIPANTS.head()
# Out:
#       participationStartDate  age gender  openness  conscientiousness  \
# pcode
# P01               2019-05-08   27      M        11                 11
# P02               2019-05-08   21      M        14                  5
# P03               2019-05-08   24      F        10                 15
# P04               2019-05-08   23      M        12                 11
# P05               2019-05-08   27      F        10                 11
#
#        neuroticism  extraversion  agreeableness  PSS  PHQ  GHQ  \
# pcode
# P01              3             4             13   13    0    1
# P02             12            14              5   27    6   18
# P03              8             7             11   18    2    6
# P04              8             6             11   20    1    9
# P05             13            10              6   25   14    9
#
#       particpationStartDateTime
# pcode
# P01   2019-05-08 00:00:00+09:00
# P02   2019-05-08 00:00:00+09:00
# P03   2019-05-08 00:00:00+09:00
# P04   2019-05-08 00:00:00+09:00
# P05   2019-05-08 00:00:00+09:00

# %% [markdown]
# Belows are some demographics:

# %%
for c in PARTICIPANTS.columns:
    print(f'- {c}:', summary(PARTICIPANTS[c]))
# Out:
# - participationStartDate: {'n': 77, 'cardinality': 3, 'value_count': '2019-05-08:27, 2019-05-16:25, 2019-04-30:25'}
# - age: {'n': 77, 'sum': 1686, 'mean': 21.896103896103895, 'SD': 3.8613619617422406, 'med': 21.0, 'range': (17, 38), 'conf.': (21.019682236199852, 22.77252555600794), 'nan_count': 0}
# - gender: {'n': 77, 'cardinality': 2, 'value_count': 'M:53, F:24'}
# - openness: {'n': 77, 'sum': 787, 'mean': 10.220779220779221, 'SD': 2.8956563505732467, 'med': 11.0, 'range': (3, 15), 'conf.': (9.563545848092234, 10.878012593466208), 'nan_count': 0}
# - conscientiousness: {'n': 77, 'sum': 820, 'mean': 10.64935064935065, 'SD': 2.3662441579221882, 'med': 11.0, 'range': (5, 15), 'conf.': (10.112279104861539, 11.18642219383976), 'nan_count': 0}
# - neuroticism: {'n': 77, 'sum': 618, 'mean': 8.025974025974026, 'SD': 2.6900108881310953, 'med': 8.0, 'range': (3, 14), 'conf.': (7.4154164478204185, 8.636531604127633), 'nan_count': 0}
# - extraversion: {'n': 77, 'sum': 703, 'mean': 9.12987012987013, 'SD': 3.0015375417426937, 'med': 9.0, 'range': (3, 15), 'conf.': (8.448604674659734, 9.811135585080525), 'nan_count': 0}
# - agreeableness: {'n': 77, 'sum': 805, 'mean': 10.454545454545455, 'SD': 2.526415468527935, 'med': 11.0, 'range': (5, 15), 'conf.': (9.881119481929446, 11.027971427161464), 'nan_count': 0}
# - PSS: {'n': 77, 'sum': 1294, 'mean': 16.805194805194805, 'SD': 7.178254737745983, 'med': 16.0, 'range': (3, 32), 'conf.': (15.17593083180889, 18.434458778580723), 'nan_count': 0}
# - PHQ: {'n': 77, 'sum': 380, 'mean': 4.935064935064935, 'SD': 4.609308837152732, 'med': 4.0, 'range': (0, 19), 'conf.': (3.8888801582705144, 5.981249711859356), 'nan_count': 0}
# - GHQ: {'n': 77, 'sum': 780, 'mean': 10.12987012987013, 'SD': 5.894579689829796, 'med': 10.0, 'range': (1, 27), 'conf.': (8.791964653154256, 11.467775606586002), 'nan_count': 0}
# - particpationStartDateTime: {'n': 77, 'cardinality': 3, 'value_count': '2019-05-08 00:00:00+09:00:27, 2019-05-16 00:00:00+09:00:25, 2019-04-30 00:00:00+09:00:25'}

# %% [markdown]
# ## Labels (via ESM)

# %%
import pandas as pd
import os


LABELS = pd.read_csv(PATH_ESM).set_index(
    ['pcode']
)
LABELS.head()
# Out:
#         responseTime  scheduledTime  valence  arousal  attention  stress  \
# pcode
# P01    1557278103000            NaN        0        0          0      -1
# P01    1557278986000   1.557279e+12       -3        3          3       3
# P01    1557281772000   1.557282e+12       -3       -2          2       2
# P01    1557287138000            NaN        2       -1          2       0
# P01    1557291117000            NaN        3        3          3      -3
#
#        duration  disturbance  change
# pcode
# P01        20.0            3      -2
# P01         5.0           -1      -3
# P01        15.0            3      -2
# P01        15.0            1      -1
# P01        20.0            1       0

# %%
for c in LABELS.columns:
    print(f'- {c}:', summary(LABELS[c]))
# Out:
# - responseTime: {'n': 5582, 'sum': 8694314195328000, 'mean': 1557562557385.8833, 'SD': 590915040.4254278, 'med': 1557562969500.0, 'range': (1556582982000, 1558545246000), 'conf.': (1557547052362.8618, 1557578062408.9048), 'nan_count': 0}
# - scheduledTime: {'n': 5582, 'sum': 5175814282500000.0, 'mean': 1557572760306.9517, 'SD': 591697484.8543198, 'med': 1557565860000.0, 'range': (1556586120000.0, nan), 'conf.': (1557552635074.4736, 1557592885539.4297), 'nan_count': 2259}
# - valence: {'n': 5582, 'sum': 3665, 'mean': 0.6565747044070226, 'SD': 1.4184297545899174, 'med': 1.0, 'range': (-3, 3), 'conf.': (0.6193565182132938, 0.6937928906007513), 'nan_count': 0}
# - arousal: {'n': 5582, 'sum': -529, 'mean': -0.09476890003582945, 'SD': 1.6675313128774563, 'med': 0.0, 'range': (-3, 3), 'conf.': (-0.13852326339835566, -0.051014536673303246), 'nan_count': 0}
# - attention: {'n': 5582, 'sum': 2236, 'mean': 0.4005732712289502, 'SD': 1.6113242733571864, 'med': 1.0, 'range': (-3, 3), 'conf.': (0.3582937246879792, 0.4428528177699212), 'nan_count': 0}
# - stress: {'n': 5582, 'sum': -1450, 'mean': -0.25976352561805804, 'SD': 1.6154902647587075, 'med': 0.0, 'range': (-3, 3), 'conf.': (-0.30215238363050767, -0.21737466760560845), 'nan_count': 0}
# - duration: {'n': 5582, 'sum': 141955.0, 'mean': 26.390593047034766, 'SD': 18.060980770860386, 'med': 20.0, 'range': (5.0, nan), 'conf.': (25.90782735251826, 26.87335874155127), 'nan_count': 203}
# - disturbance: {'n': 5582, 'sum': -243, 'mean': -0.04353278394840559, 'SD': 1.7587124884936127, 'med': 0.0, 'range': (-3, 3), 'conf.': (-0.0896796506833856, 0.0026140827865744204), 'nan_count': 0}
# - change: {'n': 5582, 'sum': -52, 'mean': -0.009315657470440702, 'SD': 0.9046571244275675, 'med': 0.0, 'range': (-3, 3), 'conf.': (-0.03305296077324875, 0.014421645832367342), 'nan_count': 0}

# %% [markdown]
# Belows are some demographics:

# %%
inst = LABELS.groupby('pcode').count().iloc[:, -1]
inst_sch = LABELS.loc[lambda x: ~x['scheduledTime'].isna(), :].groupby('pcode').count().iloc[:, -1]
inst_vol = LABELS.loc[lambda x: x['scheduledTime'].isna(), :].groupby('pcode').count().iloc[:, -1]
resp_time = LABELS.assign(
    timestamp=lambda x: pd.to_datetime(x['responseTime'], unit='ms', utc=True).dt.tz_convert(DEFAULT_TZ)
)
sam = np.concatenate([
    (resp_time.loc[p, 'timestamp'].array - resp_time.loc[p, 'timestamp'].array.shift(1)).dropna().total_seconds()
    for p in LABELS.index.unique()
])

print('- # Inst.:', summary(inst))
print('- # Inst. - Scheduled:', summary(inst_sch))
print('- # Inst. - Voluntary:', summary(inst_vol))
print('- Samp. period:', summary(sam))
for c in LABELS.columns:
    print(f'- {c}:', summary(LABELS[c]))
# Out:
# - # Inst.: {'n': 77, 'sum': 5582, 'mean': 72.49350649350649, 'SD': 16.02270048911147, 'med': 74.0, 'range': (20, 110), 'conf.': (68.85679957559911, 76.13021341141386), 'nan_count': 0}
# - # Inst. - Scheduled: {'n': 76, 'sum': 3323, 'mean': 43.723684210526315, 'SD': 19.36291898394835, 'med': 43.5, 'range': (3, 83), 'conf.': (39.29906768359284, 48.14830073745979), 'nan_count': 0}
# - # Inst. - Voluntary: {'n': 77, 'sum': 2259, 'mean': 29.337662337662337, 'SD': 16.297893300742235, 'med': 27.0, 'range': (2, 74), 'conf.': (25.638494313245726, 33.03683036207895), 'nan_count': 0}
# - Samp. period: {'n': 5505, 'sum': 42240670.0, 'mean': 7673.146230699364, 'SD': 13193.471538029606, 'med': 3090.0, 'range': (1.0, 136446.0), 'conf.': (7324.548923384188, 8021.743538014541), 'nan_count': 0}
# - responseTime: {'n': 5582, 'sum': 8694314195328000, 'mean': 1557562557385.8833, 'SD': 590915040.4254278, 'med': 1557562969500.0, 'range': (1556582982000, 1558545246000), 'conf.': (1557547052362.8618, 1557578062408.9048), 'nan_count': 0}
# - scheduledTime: {'n': 5582, 'sum': 5175814282500000.0, 'mean': 1557572760306.9517, 'SD': 591697484.8543198, 'med': 1557565860000.0, 'range': (1556586120000.0, nan), 'conf.': (1557552635074.4736, 1557592885539.4297), 'nan_count': 2259}
# - valence: {'n': 5582, 'sum': 3665, 'mean': 0.6565747044070226, 'SD': 1.4184297545899174, 'med': 1.0, 'range': (-3, 3), 'conf.': (0.6193565182132938, 0.6937928906007513), 'nan_count': 0}
# - arousal: {'n': 5582, 'sum': -529, 'mean': -0.09476890003582945, 'SD': 1.6675313128774563, 'med': 0.0, 'range': (-3, 3), 'conf.': (-0.13852326339835566, -0.051014536673303246), 'nan_count': 0}
# - attention: {'n': 5582, 'sum': 2236, 'mean': 0.4005732712289502, 'SD': 1.6113242733571864, 'med': 1.0, 'range': (-3, 3), 'conf.': (0.3582937246879792, 0.4428528177699212), 'nan_count': 0}
# - stress: {'n': 5582, 'sum': -1450, 'mean': -0.25976352561805804, 'SD': 1.6154902647587075, 'med': 0.0, 'range': (-3, 3), 'conf.': (-0.30215238363050767, -0.21737466760560845), 'nan_count': 0}
# - duration: {'n': 5582, 'sum': 141955.0, 'mean': 26.390593047034766, 'SD': 18.060980770860386, 'med': 20.0, 'range': (5.0, nan), 'conf.': (25.90782735251826, 26.87335874155127), 'nan_count': 203}
# - disturbance: {'n': 5582, 'sum': -243, 'mean': -0.04353278394840559, 'SD': 1.7587124884936127, 'med': 0.0, 'range': (-3, 3), 'conf.': (-0.0896796506833856, 0.0026140827865744204), 'nan_count': 0}
# - change: {'n': 5582, 'sum': -52, 'mean': -0.009315657470440702, 'SD': 0.9046571244275675, 'med': 0.0, 'range': (-3, 3), 'conf.': (-0.03305296077324875, 0.014421645832367342), 'nan_count': 0}

# %% [markdown]
# ### Plot

# %%
data = LABELS.loc[
    :, lambda x: ~x.columns.isin(['responseTime', 'scheduledTime'])
]

# %%
# %%R -i data -w 16 -h 6 -u cm

# data <- data %>% pivot_longer(
#     cols = c('valence', 'arousal', 'attention', 'stress', 'duration', 'disturbance', 'change'),
#     names_to = 'metric'
# )

# p_rest <- ggplot(
#     data %>% filter(metric != 'duration'), aes(x=metric, y=value)
# ) + geom_boxplot(
# ) + geom_point(
#     data = data %>% filter(
#         metric != 'duration'
#     ) %>% group_by(
#         metric
#     ) %>% summarise(
#         mean = mean(value, na.rm=TRUE)
#     ),
#     mapping=aes(x=metric, y=mean),
#     shape=21,
#     stroke=1,
#     size=2,
#     fill='white'
# ) + scale_x_discrete(
#     name=NULL,
#     limits=c('valence', 'arousal', 'stress', 'attention', 'disturbance', 'change'),
#     labels=c('Valence', 'Arousal', 'Stress', 'Attent.', 'Disturb.', 'Change'),
# ) + scale_y_continuous(
#     name='Response',
#     breaks=-3:3
# ) + THEME_DEFAULT

# p_duration <- ggplot(
#     data %>% filter(metric == 'duration'), aes(x=metric, y=value)
# ) + geom_boxplot(
# ) + geom_point(
#     data = data %>% filter(
#         metric == 'duration'
#     ) %>% group_by(
#         metric
#     ) %>% summarise(
#         mean = mean(value, na.rm=TRUE)
#     ),
#     mapping=aes(x=metric, y=mean),
#     shape=21,
#     stroke=1,
#     size=2,
#     fill='white'
# )+ scale_x_discrete(
#     name=NULL,
#     limits=c('duration'),
#     labels=c('Duration'),
# ) + scale_y_continuous(
#     name=NULL,
#     breaks=seq(from=5, to=60, by=10)
# ) + THEME_DEFAULT

# p <- p_rest + p_duration + plot_layout(widths=c(4, 0.8))
# ggsave('./fig/dist-labels.pdf', plot=p, width=16, height=6, unit='cm', device=cairo_pdf)
# print(p)

# %% [markdown]
# ### Correlation

# %% [markdown]
# Because each participant reported their labels multiple times (i.e., repeated measure), repeated measure correlation between affect labels were used.

# %%
data = LABELS.reset_index()[[
    'pcode', 'valence', 'arousal', 'stress', 'attention', 'disturbance', 'change'
]]

# %%
# %%R -i data 

# com <- combn(c('valence', 'arousal', 'stress', 'attention', 'disturbance', 'change'), 2)

# for(i in 1:ncol(com)) {
#     a <- com[, i][1]
#     b <- com[, i][2]
#     r <- rmcorr(participant = 'pcode', measure1=a, measure2=b, dataset=data)
#     cat(a, '-', b, ': R =', r$r, '(p =', r$p, ') \n')
# }

# %% [markdown]
# ## Sensor Data

# %%
import os
import pandas as pd
from typing import Optional


def _load_data(
    name: str
) -> Optional[pd.DataFrame]:
    paths = [
        (d, os.path.join(PATH_SENSOR, d, f'{name}.csv'))
        for d in os.listdir(PATH_SENSOR)
        if d.startswith('P')
    ]
    return pd.concat(
        filter(
            lambda x: len(x.index), 
            [
                pd.read_csv(p).assign(pcode=pcode)
                for pcode, p in paths
                if os.path.exists(p)
            ]
        ), ignore_index=True
    ).assign(
        timestamp=lambda x: pd.to_datetime(x['timestamp'], unit='ms', utc=True).dt.tz_convert(DEFAULT_TZ)
    ).set_index(
        ['pcode', 'timestamp']
    )

# %%
import pandas as pd
import gc
from datetime import timedelta as td


# STATS = []

# for data_type in DATA_TYPES:
#     dat = _load_data(data_type)
#     inst = dat.groupby('pcode').count().iloc[:, -1]
#     samp = np.concatenate([
#         (dat.loc[(p,), :].index.array - dat.loc[(p,), :].index.array.shift(1)).dropna().total_seconds()
#         for p in dat.index.get_level_values('pcode').unique()
#     ])
#     inst, samp = summary(inst), summary(samp)
    
#     print('#'*5, data_type, '#'*5)
#     print('- # Inst.:', inst)
#     print('- Samp. period:', samp)
    
#     for c in dat.columns:
#         print(f'- {c}:', summary(dat[c]))
        
#     del dat
#     gc.collect()
    
# STATS = pd.DataFrame(STATS)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Label
#
# Because we intended to collected participants' responses to ESMs not voluntary responses, we screend out some responses as follows:
# * We first screen out ESM responses that does not have 'scheduledTime' (meaning that a given ESM was expired or participants voluntarily reported their affective states regardless of ESM delivery).
# * Since we will evaluate our model using LOSO, the small number of responses for each participant might lead to inappropriate performance evaluation. We emprically set the number of the minimum responses upon ESM delivery as 5 per day (i.e., a half of our guides), so that we excluded participants whose responses to ESM less than 35.

# %%
LABELS_VALID = LABELS.loc[
    lambda x: ~x['scheduledTime'].isna(), :
]
print(f'# Non-voluntary response: {len(LABELS_VALID)}')
print(summary(LABELS_VALID.groupby('pcode').count().iloc[:, -1]))

excl_pcode = LABELS_VALID.loc[
    lambda x: ~x['scheduledTime'].isna()
].groupby('pcode').count().iloc[:, -1].loc[lambda y: y < 35]

LABELS_VALID = LABELS_VALID.loc[
    lambda x:  ~x.index.get_level_values('pcode').isin(excl_pcode.index), :
]
print(f'# Response from participants with enough responses: {len(LABELS_VALID)}')
print(summary(LABELS_VALID.groupby('pcode').count().iloc[:, -1]))

print('# Participants whose responses to ESM delivery were less then 35')
print(excl_pcode, f'#participants = {len(excl_pcode)} / #response = {sum(excl_pcode)}')

# LABELS_VALID # 47명 데이터 only
# Out:
# # Non-voluntary response: 3323
# {'n': 76, 'sum': 3323, 'mean': 43.723684210526315, 'SD': 19.36291898394835, 'med': 43.5, 'range': (3, 83), 'conf.': (39.29906768359284, 48.14830073745979), 'nan_count': 0}
# # Response from participants with enough responses: 2619
# {'n': 47, 'sum': 2619, 'mean': 55.723404255319146, 'SD': 13.076201628480542, 'med': 52.0, 'range': (36, 83), 'conf.': (51.88408763344431, 59.56272087719398), 'nan_count': 0}
# # Participants whose responses to ESM delivery were less then 35
# pcode
# P04    34
# P07    24
# P11    22
# P14    11
# P16    30
# P17    13
# P18    32
# P20    31
# P22    23
# P24    10
# P25    30
# P29    32
# P34    22
# P36    29
# P37    31
# P38    33
# P41    31
# P43    24
# P44    23
# P46     4
# P54    13
# P56    31
# P58    29
# P62     3
# P63    34
# P64    30
# P68    11
# P73    31
# P74    33
# Name: change, dtype: int64 #participants = 29 / #response = 704

# %% [markdown]
# Here we consider binary classifications for valence, arousal, stress, and disturbance, in which a label value greater than 0 is "HIGH" (1) and the rest is "LOW" (0), at the arrival of ESM prompts (*scheduledTime*)

# %%
import pandas as pd
import numpy as np

LABELS_PROC = (
    LABELS # LABELS_VALID
    .reset_index()
    .assign(
        timestamp=lambda x: pd.to_datetime(x['scheduledTime'], unit='ms', utc=True).dt.tz_convert(DEFAULT_TZ),
        attention_bin=lambda x: np.where(x['attention'] > 0, 1, 0)
    )
    .loc[:, ['pcode', 'timestamp', 'attention', 'attention_bin']]  # attention: 연속형, attention_bin: 이진분류된 데이터
    .set_index(['pcode', 'timestamp'])
)

LABELS_PROC
# Out:
# /home/yeji0501/miniconda3/envs/sci-data/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:557: RuntimeWarning: invalid value encountered in cast
#   arr, tz_parsed = tslib.array_with_unit_to_datetime(arg, unit, errors=errors)
#                                  attention  attention_bin
# pcode timestamp
# P01   NaT                                0              0
#       2019-05-08 10:26:00+09:00          3              1
#       2019-05-08 11:13:00+09:00          2              1
#       NaT                                2              1
#       NaT                                3              1
# ...                                    ...            ...
# P80   2019-05-06 15:53:00+09:00          3              1
#       NaT                                3              1
#       NaT                               -2              0
#       2019-05-06 19:39:00+09:00         -1              0
#       2019-05-06 21:08:00+09:00          3              1
#
# [5582 rows x 2 columns]

# %%
import numpy as np


inst = LABELS_PROC.groupby('pcode').count().iloc[:, -1]
for c in [c for c in LABELS_PROC.columns if c.endswith('_bin')]:
    print(f'- {c}:', summary(LABELS_PROC[c].astype(object)))
# Out:
# - attention_bin: {'n': 5582, 'cardinality': 2, 'value_count': '1:2806, 0:2776'}

# %% [markdown]
# ## Sensor Data

# %% [markdown]
# For each type of sensor data, we applied different preprocessing. Detailed decsription is provided in the paper.

# %% [markdown]
# ### Implementation

# %%
import pandas as pd
import numpy as np
import scipy.spatial.distance as dist
from typing import Dict, Union
import pygeohash as geo
from datetime import timedelta
from collections import defaultdict
# # SkinTemperature.csv
# def _proc_skin_temperature(data: pd.DataFrame) -> Union[pd.Series, Dict[str, pd.Series]]:
#     return data['temperature'].astype('float32')

# RRI.csv
def _proc_rri(data: pd.DataFrame) -> Union[pd.Series, Dict[str, pd.Series]]:
    return data['interval'].astype('float32')

# # HR.csv
# def _proc_hr(data: pd.DataFrame) -> Union[pd.Series, Dict[str, pd.Series]]:
#     return data['bpm'].astype('float32')
    
# # EDA.csv
# def _proc_eda(data: pd.DataFrame) -> Union[pd.Series, Dict[str, pd.Series]]:
#     return data['resistance'].astype('float32')

# %% [markdown]
# ### Execution

# %%
import pandas as pd
import gc
from functools import reduce
import time

FUNC_PROC = {
#    'EDA': _proc_eda,
#    'HR': _proc_hr,
    'RRI': _proc_rri,
#    'SkinTemperature': _proc_skin_temperature,
}


def _process(data_type: str):
    log(f'Begin to processing data: {data_type}')
    
    abbrev = DATA_TYPES[data_type]
    data_raw = _load_data(data_type)
    data_proc = FUNC_PROC[data_type](data_raw)
    result = dict()
    
    if type(data_proc) is dict:
        for k, v in data_proc.items():
            result[f'{abbrev}_{k}'] = v
    else:
        result[abbrev] = data_proc
        
    log(f'Complete processing data: {data_type}')
    return result


with on_ray(num_cpus=12):
    jobs = []
    
    func = ray.remote(_process).remote
    
    for data_type in DATA_TYPES:
        job = func(data_type)
        jobs.append(job)

    jobs = ray.get(jobs)
    
    # 메모리 최적화를 위해 추가 
    combined_result = {}
    for d in jobs:
        combined_result |= d
    
    t0 = time.time()
    dump(combined_result, os.path.join(PATH_INTERMEDIATE, 'proc.pkl'))
    log(f'[SAVE] done in {time.time() - t0:.1f}s')
    
    del jobs
    gc.collect()
# Out:
# 2025-05-21 02:11:36,221	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (_process pid=4317) [25-05-21 02:11:37] Begin to processing data: RRI
# (_process pid=4317) [25-05-21 02:11:57] Complete processing data: RRI
# [25-05-21 02:12:00] [SAVE] done in 2.6s

# %%
import os
import gc

DATA = load(os.path.join(PATH_INTERMEDIATE, 'proc.pkl'))
#categorial, numeric 변수 수 계산
N_NUMERIC, N_CATEGORICAL = 0, 0

for k, v in DATA.items():
    if v.dtype.kind.isupper() or v.dtype.kind == 'b': 
        N_CATEGORICAL = N_CATEGORICAL + 1
    else:
        N_NUMERIC = N_NUMERIC + 1
        
    inst = v.groupby('pcode').count()
    sam = np.concatenate([
        (v.loc[(p,)].index.array - v.loc[(p,)].index.array.shift(1)).dropna().total_seconds()
        for p in v.index.get_level_values('pcode').unique()
    ])
    
    print('#'*5, k, '#'*5, )
    print('- # Inst.:', summary(inst))
    print('- Samp. period:', summary(sam))
    print('- Values', summary(v))
    print('')
    
    
print(f'# categorical data: {N_CATEGORICAL}/# numeric data: {N_NUMERIC}')
del DATA
gc.collect()
# Out:
# ##### RRI #####
# - # Inst.: {'n': 77, 'sum': 20764471, 'mean': 269668.45454545453, 'SD': 81037.2444152014, 'med': 279148.0, 'range': (81185, 439154), 'conf.': (251275.25624700362, 288061.65284390544), 'nan_count': 0}
# - Samp. period: {'n': 20764394, 'sum': 41213534.84999999, 'mean': 1.9848176089319045, 'SD': 276.2002925233019, 'med': 0.762, 'range': (0.001, 347548.529), 'conf.': (1.8660186540337333, 2.1036165638300757), 'nan_count': 0}
# - Values {'n': 20764471, 'sum': 15700590000.0, 'mean': 756.1276, 'SD': 178.71399, 'med': 763.232, 'range': (298.656, 1493.28), 'conf.': (756.0507563969516, 756.204492626486), 'nan_count': 0}
#
# # categorical data: 0/# numeric data: 1
# 0

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# ## Implementation

# %%
import numpy as np
import pandas as pd
from typing import Dict, Callable, Union, Tuple, List, Optional, Iterable
from datetime import timedelta as td
from scipy import stats
from scipy.interpolate import CubicSpline
import ray
import warnings
import time
import json

# _extract: 한 명의 참가자로부터 feature 추출
# data, label(timestamp별 정답값), label_values(라벨 클래스 목록), window_data, window_label, categories, const_features, resample
# time window별 통합: 수치형 센서 - mean, std, skewness, kurtosis, median, 시계열 복잡도, 변화량 절댓값 합, 히스토그램 기반 엔트로피
# 시간대별 패턴: 비정기적 설문조사 주기에 맞게 하루를 7개의 시간대로 분할, one-hot encoding 
# 최종 feature 예시: ESM#LIK#H24
# extract: 여러 참가자에게 _extract함수 -> 통합

# 최종 학습 데이터 형태: X(각 참가자, 각 시점에 대한 Feature, DataFrame), y(label, ndarray), group(LOSO시 각 행에 속한 참가자 ID, ndarray), t_norm(응답시간 timestamp를 정규화한 시간 정보), date_times(각 데이터 포인트으ㅢ 실제 timestamp)
# X: PIF#AGE, ACC#AVG#H06, APP_CAT#DUR=COMMUNICATION#H01, ESM#HRN=MORNING  . . .
# y: np.array([1, 0, 1, 1  . . .
# group:  np.array(['P01', 'P01', 'P02' . . .
# t_norm: np.array([0.0, 10800.0, 3600.0, 7200.0 . . .
# date_times: np.array([
#     Timestamp('2025-05-01 10:00:00'),
#     Timestamp('2025-05-01 13:00:00'),
#     Timestamp('2025-05-01 11:00:00'), . . .

def _safe_na_check(_v):
    _is_nan_inf = False
    try:
        _is_nan_inf = np.isnan(_v) or np.isinf(_v)
    except:
        _is_nan_inf = False
    return _is_nan_inf or _v is None


def _extract(
        pid: str,
        data: Dict[str, pd.Series],
        label: pd.Series,
        label_values: List[str],
        window_data: Dict[str, Union[int, Callable[[pd.Timestamp], int]]],
        window_label: Dict[str, Union[int, Callable[[pd.Timestamp], int]]],        
        categories: Dict[str, Optional[List[any]]] = None,        
        resample_s: Dict[str, float] = None
) -> Tuple[pd.DataFrame, np.ndarray, np.ndarray, np.ndarray]:
    _s = time.time()
    log(f"Begin feature extraction on {pid}'s data.")

    categories = categories or dict()
    resample_s = resample_s or dict()

    X, y, date_times = [], [], []
    # debug_info = []
    try: 
        for timestamp in label.index:

            # 원본 코드
            # label_cur = label.at[timestamp]
            # t = timestamp - td(milliseconds=1)
            # if pd.isnull(label_cur):
            #     continue

            ## 디버깅용 추가 코드 : index type 오류 문제 해결 시도 

             # MultiIndex (예: (pcode, timestamp)) 처리
            if isinstance(timestamp, tuple):
                # 마지막 값이 timestamp라고 가정
                ts = timestamp[-1]
            else:
                ts = timestamp
            # ts가 pd.Timestamp가 아니거나 NaT면 건너뜀 => 로직 맞는지 점검 필요요
            if not isinstance(ts, pd.Timestamp) or pd.isnull(ts):
                continue
            t = ts - td(milliseconds=1)
            if pd.isnull(t):
                continue
            label_cur = label.at[timestamp]
            if pd.isnull(label_cur):
                continue
            row = dict()

            # Features from sensor data
            for d_key, d_val in data.items():
                is_numeric = d_key not in categories
                cats = categories.get(d_key) or list()
                d_val = d_val.sort_index()

                # 인덱스 타입 체크 및 변환
                if not isinstance(d_val.index, pd.DatetimeIndex):
                    try:
                        d_val.index = pd.to_datetime(d_val.index)
                    except Exception as e:
                        raise ValueError(f"{d_key}의 인덱스를 DatetimeIndex로 변환할 수 없습니다: {e}")

                if is_numeric or cats:
                    try:
                        v = d_val.loc[:t].iloc[-1]
                    except (KeyError, IndexError):
                        v = 0

                    if is_numeric:
                        row[f'{d_key}#VAL'] = v
                    else:
                        for c in cats:
                            row[f'{d_key}#VAL={c}'] = v == c

                # catogorial 데이터의 최근 상태 변화 시간 => 현재 category 정보는 사용하지 않으므로 주석 처리.
                

                # if not is_numeric:
                #     try:
                #         v = d_val.loc[:t]

                #         # 추가된 부분 : indexing 시 타입 맞추기 위한 방법 => debug_info 확인인
                #         row[f'{d_key}#DSC'] = (t - v.index[-1]).total_seconds() if len(v) else -1.0
                #         for c in cats:
                #             v_sub = v.loc[lambda x: x == c].index

                #             debug_info.append({
                #                 "pid": pid,
                #                 "timestamp": timestamp,
                #                 "d_key": d_key,
                #                 "cat": c,
                #                 "v_sub_type": str(type(v_sub)),
                #                 "v_sub": str(v_sub),
                #             })

                #             if len(v_sub):
                #                 last_idx = v_sub[-1]       
                #                 debug_info.append({
                #                     "last_idx_type": str(type(last_idx)),
                #                     "last_idx": str(last_idx),
                #                 })
                #                 if isinstance(last_idx, pd.Timestamp):
                #                     row[f'{d_key}#DSC={c}'] = (t - last_idx).total_seconds()
                #                 else:
                #                     # 만약 float 등 잘못된 값이면 -1.0으로 처리
                #                     row[f'{d_key}#DSC={c}'] = -1.0
                #             else:
                #                 row[f'{d_key}#DSC={c}'] = -1.0
                #     except (KeyError, IndexError):
                #         row[f'{d_key}#DSC'] = -1.0
                #         for c in cats:
                #             row[f'{d_key}#DSC={c}'] = -1.0

                # Time-window 기반 피처 (resampling 포함)
                sample_rate = resample_s.get(d_key) or 1
                d_val_res = d_val.resample(sample_rate, origin='start')
                if is_numeric:
                    """ 보간 방식 추가 부분 """
                    if d_key == "interval":
                        interval_series = d_val.dropna()
                        if len(interval_series) >= 4:
                            ts = interval_series.index.view(np.int64) // 10**6
                            cs = CubicSpline(ts, interval_series.values)
                            full_ts = d_val.index.view(np.int64) // 10**6
                            d_val[:] = cs(full_ts)
                    else: 
                        d_val_res = d_val_res.mean().interpolate(method='linear', limit_direction= 'both').dropna()
                else:
                    d_val_res = d_val_res.ffill().dropna()

                for w_key, w_val in window_data.items():
                    w_val = w_val(t) if isinstance(w_val, Callable) else w_val
                    try:
                        v = d_val_res.loc[t - td(seconds=w_val):t]
                        # numeric 데이터일 경우에만 변환
                        if is_numeric:
                            v_arr = v.values.astype(np.float64)
                        else:
                            v_arr = v
                    except (KeyError, IndexError):
                        continue

                    with warnings.catch_warnings():
                        warnings.simplefilter('ignore')

                        if is_numeric:
                            hist, _ = np.histogram(v, bins='doane', density=False)
                            std = np.sqrt(np.var(v, ddof=1)) if len(v) > 1 else 0
                            v_norm = (v - np.mean(v)) / std if std != 0 else np.zeros(len(v))

                            row[f'{d_key}#AVG#{w_key}'] = np.float32(np.mean(v_arr))
                            row[f'{d_key}#STD#{w_key}'] = np.float32(std)
                            row[f'{d_key}#SKW#{w_key}'] = np.float32(stats.skew(v_arr, bias=False))
                            row[f'{d_key}#KUR#{w_key}'] = np.float32(stats.kurtosis(v_arr, bias=False))
                            row[f'{d_key}#ASC#{w_key}'] = np.float32(np.sum(np.abs(np.diff(v_arr))))
                            row[f'{d_key}#BEP#{w_key}'] = np.float32(stats.entropy(hist))
                            row[f'{d_key}#MED#{w_key}'] = np.float32(np.median(v_arr))
                            row[f'{d_key}#TSC#{w_key}'] = np.float32(np.sqrt(np.sum(np.power(np.diff(v_norm), 2))))
                        else:
                            cnt = v.value_counts()
                            val, sup = cnt.index, cnt.values
                            hist = {k: v for k, v in zip(val, sup)}

                            row[f'{d_key}#ETP#{w_key}'] = stats.entropy(sup / len(v))
                            row[f'{d_key}#ASC#{w_key}'] = np.sum(np.array(v.values)[1:] != v.values[:-1])

                            if len(cats) == 2:
                                c = cats[0]
                                row[f'{d_key}#DUR#{w_key}'] = hist[c] / len(v) if c in hist else 0
                            else:
                                for c in cats:
                                    row[f'{d_key}#DUR={c}#{w_key}'] = hist[c] / len(v) if c in hist else 0

            # 시간 기반 피처
            day_of_week = ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN'][t.isoweekday() - 1]
            is_weekend = 'Y' if t.isoweekday() > 5 else 'N'
            hour = t.hour

            if 6 <= hour < 9:
                hour_name = 'DAWN'
            elif 9 <= hour < 12:
                hour_name = 'MORNING'
            elif 12 <= hour < 15:
                hour_name = 'AFTERNOON'
            elif 15 <= hour < 18:
                hour_name = 'LATE_AFTERNOON'
            elif 18 <= hour < 21:
                hour_name = 'EVENING'
            elif 21 <= hour < 24:
                hour_name = 'NIGHT'
            else:
                hour_name = 'MIDNIGHT'

            for d in ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']:
                row[f'ESM#DOW={d}'] = d == day_of_week

            for d in ['Y', 'N']:
                row[f'ESM#WKD={d}'] = d == is_weekend

            for d in ['DAWN', 'MORNING', 'AFTERNOON', 'LATE_AFTERNOON', 'EVENING', 'NIGHT', 'MIDNIGHT']:
                row[f'ESM#HRN={d}'] = d == hour_name

            # 응답 이력 기반 피처
            for w_key, w_val in window_label.items():
                w_val = w_val(t) if isinstance(w_val, Callable) else w_val
                try:
                    v = label.loc[t - td(seconds=w_val):t]
                    if len(label_values) <= 2:
                        row[f'ESM#LIK#{w_key}'] = np.sum(v == label_values[0]) / len(v) if len(v) > 0 else 0
                    else:
                        for l in label_values:
                            row[f'ESM#LIK={l}#{w_key}'] = np.sum(v == l) / len(v) if len(v) > 0 else 0
                except (KeyError, IndexError):
                    if len(label_values) <= 2: 
                        row[f'ESM#LIK#{w_key}'] = 0
                    else:
                        for l in label_values:
                            row[f'ESM#LIK={l}#{w_key}'] = 0

            row = {
                k: 0.0 if _safe_na_check(v) else v
                for k, v in row.items()
            }
            X.append(row)
            y.append(label_cur)
            date_times.append(timestamp)

        log(f"Complete feature extraction on {pid}'s data ({time.time() - _s:.2f} s).")
        X, y, group, date_times = pd.DataFrame(X), np.asarray(y), np.repeat(pid, len(y)), np.asarray(date_times)

    except Exception as e:
        # # 에러 발생 시 현재까지의 row, d_key, d_val, t 등 저장
        # with open(f'error_debug_{pid}.json', 'w', encoding='utf-8') as f:
        #     json.dump({
        #         "pid": pid,
        #         "timestamp": str(timestamp),
        #         "d_key": d_key,
        #         "d_val_index_type": str(type(d_val.index)),
        #         "d_val_index_sample": str(d_val.index[:5].tolist()),
        #         "t": str(t),
        #         "error": str(e)
        #     }, f, ensure_ascii=False, indent=2)
        # raise e
        raise e
    
    return X, y, group, date_times # , debug_info



def extract(
        pids: Iterable[str],
        data: Dict[str, pd.Series],
        label: pd.Series,
        label_values: List[str],
        window_data: Dict[str, Union[int, Callable[[pd.Timestamp], int]]],
        window_label: Dict[str, Union[int, Callable[[pd.Timestamp], int]]],        
        categories: Dict[str, Optional[List[any]]] = None,        
        resample_s: Dict[str, float] = None,
        with_ray: bool=False
):
    if with_ray and not ray.is_initialized():
        raise EnvironmentError('Ray should be initialized if "with_ray" is set as True.')

    func = ray.remote(_extract).remote if with_ray else _extract
    jobs = []

    for pid in pids:
        d = dict()
        for k, v in data.items():
            try:
                d[k] = v.loc[(pid, )]
            except (KeyError, IndexError):
                pass

        job = func(
            pid=pid,
            data=d,
            label=label.loc[(pid, )],
            label_values=label_values,
            window_data=window_data,
            window_label=window_label,
            categories=categories,
            resample_s=resample_s
        )
        jobs.append(job)

    jobs = ray.get(jobs) if with_ray else jobs

    # # jobs에서 debug_info 추출 및 출력
    # debug_infos = []
    # for job in jobs:
    #     if len(job) == 5:  # debug_info가 포함된 경우
    #         debug_infos.extend(job[4])


    X = pd.concat([x for x, _, _, _ in jobs], axis=0, ignore_index=True)
    y = np.concatenate([x for _, x, _, _ in jobs], axis=0)
    group = np.concatenate([x for _, _, x, _ in jobs], axis=0)
    date_times = np.concatenate([x for _, _, _, x in jobs], axis=0)

    t_s = date_times.min().normalize().timestamp()
    t_norm = np.asarray(list(map(lambda x: x.timestamp() - t_s, date_times)))

    C, DTYPE = X.columns, X.dtypes

    X = X.fillna({
        **{c: False for c in C[(DTYPE == object) | (DTYPE == bool)]},
        **{c: 0.0 for c in C[(DTYPE != object) & (DTYPE != bool)]},
    }).astype({
        **{c: 'bool' for c in C[(DTYPE == object) | (DTYPE == bool)]},
        **{c: 'float32' for c in C[(DTYPE != object) & (DTYPE != bool)]},
    })

    return X, y, group, t_norm, date_times #, debug_infos

# %% [markdown]
# ## Execution

# %%
LABEL_VALUES = [1, 0]

WINDOW_DATA = {
    'S30': 30,
    'M01': 60,
    'M05': 60 * 5,
    'M10': 60 * 10,
    'M30': 60 * 30,
    'H01': 60 * 60,
    # 'H02': 60 * 60 * 2, # 추가 
    'H03': 60 * 60 * 3,
    # 'H04': 60 * 60 * 4, # 추가 
    # 'H05': 60 * 60 * 5, # 추가
    'H06': 60 * 60 * 6
}

WINDOW_LABEL = {
    'H06': 60 * 60 * 6,
    'H12': 60 * 60 * 12,
    'H24': 60 * 60 * 24,
}

RESAMPLE_s = {
    #'EDA': 0.25,
    'RRI': '500ms'
}

DATA = load(os.path.join(PATH_INTERMEDIATE, 'proc.pkl'))

# %%
with on_ray(num_cpus=12):
    l = 'attention'

    labels = LABELS_PROC[f'{l}_bin']
    pids = labels.index.get_level_values('pcode').unique()

    feat = extract(
        pids=pids, 
        data=DATA,         
        label=labels,
        label_values=LABEL_VALUES,
        window_data=WINDOW_DATA,
        window_label=WINDOW_LABEL,
        resample_s=RESAMPLE_s,
        with_ray=True
    )

    dump(feat, os.path.join(PATH_INTERMEDIATE, f'{l}.pkl'))
# Out:
# 2025-05-21 02:24:11,005	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (_extract pid=9482) [25-05-21 02:24:13] Begin feature extraction on P10's data.
# (_extract pid=9470) [25-05-21 02:24:13] Begin feature extraction on P09's data.
# (_extract pid=9451) [25-05-21 02:24:13] Begin feature extraction on P12's data.
# (_extract pid=9448) [25-05-21 02:24:13] Begin feature extraction on P11's data.
# (_extract pid=9473) [25-05-21 02:24:13] Begin feature extraction on P05's data.
# (_extract pid=9457) [25-05-21 02:24:13] Begin feature extraction on P06's data.
# (_extract pid=9465) [25-05-21 02:24:13] Begin feature extraction on P08's data.
# (_extract pid=9477) [25-05-21 02:24:13] Begin feature extraction on P04's data.
# (_extract pid=9468) [25-05-21 02:24:13] Begin feature extraction on P07's data.
# (_extract pid=9475) [25-05-21 02:24:13] Begin feature extraction on P02's data.
# (_extract pid=9479) [25-05-21 02:24:13] Begin feature extraction on P01's data.
# (_extract pid=9480) [25-05-21 02:24:13] Begin feature extraction on P03's data.
# (_extract pid=9448) [25-05-21 02:24:19] Complete feature extraction on P11's data (5.91 s).
# (_extract pid=9448) [25-05-21 02:24:19] Begin feature extraction on P13's data.
# (_extract pid=9468) [25-05-21 02:24:20] Complete feature extraction on P07's data (7.43 s).
# (_extract pid=9468) [25-05-21 02:24:20] Begin feature extraction on P14's data.
# (_extract pid=9477) [25-05-21 02:24:23] Complete feature extraction on P04's data (10.17 s).
# (_extract pid=9477) [25-05-21 02:24:23] Begin feature extraction on P15's data.
# (_extract pid=9468) [25-05-21 02:24:23] Complete feature extraction on P14's data (3.09 s).
# (_extract pid=9468) [25-05-21 02:24:24] Begin feature extraction on P16's data.
# (_extract pid=9480) [25-05-21 02:24:24] Complete feature extraction on P03's data (11.34 s).
# (_extract pid=9480) [25-05-21 02:24:24] Begin feature extraction on P17's data.
# (_extract pid=9479) [25-05-21 02:24:25] Complete feature extraction on P01's data (11.62 s).
# (_extract pid=9479) [25-05-21 02:24:25] Begin feature extraction on P18's data.
# (_extract pid=9451) [25-05-21 02:24:25] Complete feature extraction on P12's data (12.54 s).
# (_extract pid=9451) [25-05-21 02:24:26] Begin feature extraction on P19's data.
# (_extract pid=9482) [25-05-21 02:24:26] Complete feature extraction on P10's data (12.92 s).
# (_extract pid=9482) [25-05-21 02:24:26] Begin feature extraction on P20's data.
# (_extract pid=9457) [25-05-21 02:24:26] Complete feature extraction on P06's data (13.46 s).
# (_extract pid=9457) [25-05-21 02:24:26] Begin feature extraction on P21's data.
# (_extract pid=9473) [25-05-21 02:24:27] Complete feature extraction on P05's data (14.30 s).
# (_extract pid=9480) [25-05-21 02:24:27] Complete feature extraction on P17's data (2.93 s).
# (_extract pid=9480) [25-05-21 02:24:27] Begin feature extraction on P22's data.
# (_extract pid=9473) [25-05-21 02:24:27] Begin feature extraction on P23's data.
# (_extract pid=9475) [25-05-21 02:24:28] Complete feature extraction on P02's data (14.58 s).
# (_extract pid=9475) [25-05-21 02:24:28] Begin feature extraction on P24's data.
# (_extract pid=9470) [25-05-21 02:24:28] Complete feature extraction on P09's data (15.47 s).
# (_extract pid=9470) [25-05-21 02:24:28] Begin feature extraction on P25's data.
# (_extract pid=9480) [25-05-21 02:24:29] Complete feature extraction on P22's data (2.16 s).
# (_extract pid=9480) [25-05-21 02:24:29] Begin feature extraction on P26's data.
# (_extract pid=9465) [25-05-21 02:24:30] Complete feature extraction on P08's data (16.98 s).
# (_extract pid=9465) [25-05-21 02:24:30] Begin feature extraction on P28's data.
# (_extract pid=9475) [25-05-21 02:24:30] Complete feature extraction on P24's data (2.60 s).
# (_extract pid=9475) [25-05-21 02:24:30] Begin feature extraction on P29's data.
# (_extract pid=9468) [25-05-21 02:24:31] Complete feature extraction on P16's data (7.76 s).
# (_extract pid=9468) [25-05-21 02:24:31] Begin feature extraction on P30's data.
# (_extract pid=9479) [25-05-21 02:24:32] Complete feature extraction on P18's data (7.59 s).
# (_extract pid=9479) [25-05-21 02:24:32] Begin feature extraction on P31's data.
# (_extract pid=9448) [25-05-21 02:24:32] Complete feature extraction on P13's data (13.39 s).
# (_extract pid=9448) [25-05-21 02:24:32] Begin feature extraction on P32's data.
# (_extract pid=9477) [25-05-21 02:24:33] Complete feature extraction on P15's data (10.27 s).
# (_extract pid=9477) [25-05-21 02:24:33] Begin feature extraction on P33's data.
# (_extract pid=9482) [25-05-21 02:24:34] Complete feature extraction on P20's data (7.62 s).
# (_extract pid=9482) [25-05-21 02:24:34] Begin feature extraction on P34's data.
# (_extract pid=9470) [25-05-21 02:24:34] Complete feature extraction on P25's data (5.61 s).
# (_extract pid=9470) [25-05-21 02:24:34] Begin feature extraction on P35's data.
# (_extract pid=9475) [25-05-21 02:24:38] Complete feature extraction on P29's data (7.90 s).
# (_extract pid=9475) [25-05-21 02:24:38] Begin feature extraction on P36's data.
# (_extract pid=9451) [25-05-21 02:24:38] Complete feature extraction on P19's data (12.64 s).
# (_extract pid=9451) [25-05-21 02:24:38] Begin feature extraction on P37's data.
# (_extract pid=9457) [25-05-21 02:24:39] Complete feature extraction on P21's data (12.49 s).
# (_extract pid=9457) [25-05-21 02:24:39] Begin feature extraction on P38's data.
# (_extract pid=9482) [25-05-21 02:24:39] Complete feature extraction on P34's data (5.77 s).
# (_extract pid=9482) [25-05-21 02:24:39] Begin feature extraction on P39's data.
# (_extract pid=9473) [25-05-21 02:24:39] Complete feature extraction on P23's data (12.16 s).
# (_extract pid=9473) [25-05-21 02:24:39] Begin feature extraction on P40's data.
# (_extract pid=9477) [25-05-21 02:24:43] Complete feature extraction on P33's data (9.97 s).
# (_extract pid=9477) [25-05-21 02:24:43] Begin feature extraction on P41's data.
# (_extract pid=9475) [25-05-21 02:24:45] Complete feature extraction on P36's data (6.98 s).
# (_extract pid=9475) [25-05-21 02:24:45] Begin feature extraction on P42's data.
# (_extract pid=9448) [25-05-21 02:24:45] Complete feature extraction on P32's data (12.90 s).
# (_extract pid=9448) [25-05-21 02:24:45] Begin feature extraction on P43's data.
# (_extract pid=9479) [25-05-21 02:24:45] Complete feature extraction on P31's data (13.19 s).
# (_extract pid=9479) [25-05-21 02:24:45] Begin feature extraction on P44's data.
# (_extract pid=9470) [25-05-21 02:24:47] Complete feature extraction on P35's data (12.56 s).
# (_extract pid=9470) [25-05-21 02:24:47] Begin feature extraction on P46's data.
# (_extract pid=9451) [25-05-21 02:24:47] Complete feature extraction on P37's data (8.39 s).
# (_extract pid=9451) [25-05-21 02:24:47] Begin feature extraction on P45's data.
# (_extract pid=9457) [25-05-21 02:24:47] Complete feature extraction on P38's data (8.07 s).
# (_extract pid=9457) [25-05-21 02:24:47] Begin feature extraction on P47's data.
# (_extract pid=9470) [25-05-21 02:24:48] Complete feature extraction on P46's data (0.99 s).
# (_extract pid=9470) [25-05-21 02:24:48] Begin feature extraction on P48's data.
# (_extract pid=9480) [25-05-21 02:24:48] Complete feature extraction on P26's data (18.76 s).
# (_extract pid=9480) [25-05-21 02:24:48] Begin feature extraction on P49's data.
# (_extract pid=9468) [25-05-21 02:24:49] Complete feature extraction on P30's data (17.54 s).
# (_extract pid=9468) [25-05-21 02:24:49] Begin feature extraction on P50's data.
# (_extract pid=9465) [25-05-21 02:24:50] Complete feature extraction on P28's data (20.09 s).
# (_extract pid=9465) [25-05-21 02:24:50] Begin feature extraction on P51's data.
# (_extract pid=9448) [25-05-21 02:24:50] Complete feature extraction on P43's data (5.28 s).
# (_extract pid=9448) [25-05-21 02:24:51] Begin feature extraction on P52's data.
# (_extract pid=9479) [25-05-21 02:24:51] Complete feature extraction on P44's data (5.46 s).
# (_extract pid=9479) [25-05-21 02:24:51] Begin feature extraction on P53's data.
# (_extract pid=9477) [25-05-21 02:24:53] Complete feature extraction on P41's data (9.24 s).
# (_extract pid=9477) [25-05-21 02:24:53] Begin feature extraction on P54's data.
# (_extract pid=9473) [25-05-21 02:24:54] Complete feature extraction on P40's data (14.92 s).
# (_extract pid=9473) [25-05-21 02:24:54] Begin feature extraction on P55's data.
# (_extract pid=9482) [25-05-21 02:24:55] Complete feature extraction on P39's data (15.43 s).
# (_extract pid=9482) [25-05-21 02:24:55] Begin feature extraction on P56's data.
# (_extract pid=9477) [25-05-21 02:24:55] Complete feature extraction on P54's data (2.51 s).
# (_extract pid=9477) [25-05-21 02:24:55] Begin feature extraction on P57's data.
# (_extract pid=9451) [25-05-21 02:24:56] Complete feature extraction on P45's data (9.06 s).
# (_extract pid=9451) [25-05-21 02:24:56] Begin feature extraction on P58's data.
# (_extract pid=9470) [25-05-21 02:24:57] Complete feature extraction on P48's data (9.40 s).
# (_extract pid=9470) [25-05-21 02:24:57] Begin feature extraction on P60's data.
# (_extract pid=9468) [25-05-21 02:25:01] Complete feature extraction on P50's data (11.66 s).
# (_extract pid=9468) [25-05-21 02:25:01] Begin feature extraction on P61's data.
# (_extract pid=9448) [25-05-21 02:25:01] Complete feature extraction on P52's data (10.94 s).
# (_extract pid=9448) [25-05-21 02:25:01] Begin feature extraction on P62's data.
# (_extract pid=9448) [25-05-21 02:25:02] Complete feature extraction on P62's data (0.83 s).
# (_extract pid=9448) [25-05-21 02:25:02] Begin feature extraction on P63's data.
# (_extract pid=9482) [25-05-21 02:25:02] Complete feature extraction on P56's data (7.73 s).
# (_extract pid=9482) [25-05-21 02:25:03] Begin feature extraction on P64's data.
# (_extract pid=9451) [25-05-21 02:25:03] Complete feature extraction on P58's data (7.06 s).
# (_extract pid=9451) [25-05-21 02:25:03] Begin feature extraction on P66's data.
# (_extract pid=9475) [25-05-21 02:25:03] Complete feature extraction on P42's data (18.30 s).
# (_extract pid=9475) [25-05-21 02:25:03] Begin feature extraction on P67's data.
# (_extract pid=9465) [25-05-21 02:25:05] Complete feature extraction on P51's data (14.88 s).
# (_extract pid=9465) [25-05-21 02:25:05] Begin feature extraction on P68's data.
# (_extract pid=9457) [25-05-21 02:25:07] Complete feature extraction on P47's data (19.56 s).
# (_extract pid=9457) [25-05-21 02:25:07] Begin feature extraction on P69's data.
# (_extract pid=9473) [25-05-21 02:25:08] Complete feature extraction on P55's data (13.41 s).
# (_extract pid=9465) [25-05-21 02:25:08] Complete feature extraction on P68's data (2.80 s).
# (_extract pid=9465) [25-05-21 02:25:08] Begin feature extraction on P70's data.
# (_extract pid=9473) [25-05-21 02:25:08] Begin feature extraction on P71's data.
# (_extract pid=9473) [25-05-21 02:25:08] Complete feature extraction on P71's data (0.00 s).
# (_extract pid=9473) [25-05-21 02:25:08] Begin feature extraction on P72's data.
# (_extract pid=9480) [25-05-21 02:25:08] Complete feature extraction on P49's data (20.23 s).
# (_extract pid=9480) [25-05-21 02:25:08] Begin feature extraction on P73's data.
# (_extract pid=9477) [25-05-21 02:25:09] Complete feature extraction on P57's data (13.94 s).
# (_extract pid=9477) [25-05-21 02:25:09] Begin feature extraction on P74's data.
# (_extract pid=9482) [25-05-21 02:25:10] Complete feature extraction on P64's data (7.38 s).
# (_extract pid=9482) [25-05-21 02:25:10] Begin feature extraction on P75's data.
# (_extract pid=9448) [25-05-21 02:25:11] Complete feature extraction on P63's data (8.29 s).
# (_extract pid=9448) [25-05-21 02:25:11] Begin feature extraction on P76's data.
# (_extract pid=9470) [25-05-21 02:25:12] Complete feature extraction on P60's data (15.21 s).
# (_extract pid=9470) [25-05-21 02:25:12] Begin feature extraction on P77's data.
# (_extract pid=9479) [25-05-21 02:25:12] Complete feature extraction on P53's data (21.39 s).
# (_extract pid=9479) [25-05-21 02:25:12] Begin feature extraction on P78's data.
# (_extract pid=9451) [25-05-21 02:25:16] Complete feature extraction on P66's data (13.14 s).
# (_extract pid=9451) [25-05-21 02:25:16] Begin feature extraction on P79's data.
# (_extract pid=9480) [25-05-21 02:25:17] Complete feature extraction on P73's data (8.05 s).
# (_extract pid=9480) [25-05-21 02:25:17] Begin feature extraction on P80's data.
# (_extract pid=9465) [25-05-21 02:25:17] Complete feature extraction on P70's data (9.27 s).
# (_extract pid=9477) [25-05-21 02:25:17] Complete feature extraction on P74's data (8.20 s).
# (_extract pid=9468) [25-05-21 02:25:19] Complete feature extraction on P61's data (18.83 s).
# (_extract pid=9475) [25-05-21 02:25:20] Complete feature extraction on P67's data (16.21 s).
# (_extract pid=9470) [25-05-21 02:25:22] Complete feature extraction on P77's data (9.74 s).
# (_extract pid=9473) [25-05-21 02:25:23] Complete feature extraction on P72's data (15.22 s).
# (_extract pid=9479) [25-05-21 02:25:23] Complete feature extraction on P78's data (11.16 s).
# (_extract pid=9451) [25-05-21 02:25:24] Complete feature extraction on P79's data (8.06 s).
# (_extract pid=9457) [25-05-21 02:25:24] Complete feature extraction on P69's data (17.50 s).
# (_extract pid=9448) [25-05-21 02:25:25] Complete feature extraction on P76's data (14.47 s).
# (_extract pid=9482) [25-05-21 02:25:26] Complete feature extraction on P75's data (15.89 s).
# (_extract pid=9480) [25-05-21 02:25:27] Complete feature extraction on P80's data (10.10 s).

# %%
import numpy as np
import os

# attention만 대상
X, y, group, t, _ = load(os.path.join(PATH_INTERMEDIATE, 'attention.pkl'))

print(f'# attention')
print(f'- Feature space: {len(X.dtypes)}; Cat.: {np.sum(X.dtypes == bool)}; Num.: {np.sum(X.dtypes != bool)}')
print(f'- Label distribution: {np.unique(y, return_counts=True)}')

# %% [markdown]
# Let's check whether the number of features is same as intented.

# %%
N_NUM, N_CAT_B, N_CAT_NB = 0, 0, 0 

for k, v in DATA.items():
    N_NUM = N_NUM + 1

# Features relavant to delivery time
N_TIM = 7 + 2 + 7
print(f'N_TIM: {N_TIM}')
        
# Features relevant to latest value
N_VAL_NUM = N_NUM
print(f'(N_VAL_NUM: {N_VAL_NUM})')

# Features from time-windows
N_WIN_NUM = N_NUM * 8 * len(WINDOW_DATA)

print(f'N_WIN_NUM: {N_WIN_NUM}')


# Features from previous labels
N_LBL = len(WINDOW_LABEL) * (1 if len(LABEL_VALUES) <= 2 else len(LABEL_VALUES))
print(f'N_LBL: {N_LBL}')

N_FEAT = N_TIM + N_WIN_NUM + N_LBL
print(f'N_FEAT: {N_FEAT}')
# Out:
# N_TIM: 16
# (N_VAL_NUM: 1)
# N_WIN_NUM: 64
# N_LBL: 3
# N_FEAT: 83

# %% [markdown]
# Okay, features are extracted as intended.

# %% [markdown]
# # Cross-validation

# %% [markdown]
# ## Implementation

# %% [markdown]
# ### CV Pipeline

# %%
import os
import pandas as pd
import numpy as np
import traceback as tb
from contextlib import contextmanager
from typing import Tuple, Dict, Union, Generator, List
from dataclasses import dataclass
# from imblearn.over_sampling import SMOTE, SMOTENC
from sklearn.base import BaseEstimator, clone
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import StratifiedKFold, LeaveOneGroupOut, StratifiedShuffleSplit, RepeatedStratifiedKFold
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder
import time
import ray


@dataclass
class FoldResult:
    name: str
    estimator: BaseEstimator
    X_train: pd.DataFrame
    y_train: np.ndarray
    X_test: pd.DataFrame
    y_test: np.ndarray
    categories: Dict[str, Dict[int, str]] = None


def _split(
        alg: str,
        X: Union[pd.DataFrame, np.ndarray] = None,
        y: np.ndarray = None,
        groups: np.ndarray = None,
        random_state: int = None,
        n_splits: int = None,
        n_repeats: int = None,
        test_ratio: float = None
) -> Generator[Tuple[np.ndarray, np.ndarray], None, None]:
    if alg == 'holdout':
        splitter = StratifiedShuffleSplit(
            n_splits=n_splits,
            test_size=test_ratio,
            random_state=random_state
        )
    elif alg == 'kfold':
        if n_repeats and n_repeats > 1:
            splitter = RepeatedStratifiedKFold(
                n_splits=n_splits,
                n_repeats=n_repeats,
                random_state=random_state,
            )
        else:
            splitter = StratifiedKFold(
                n_splits=n_splits,
                random_state=random_state,
                shuffle=False if random_state is None else True,
            )
    elif alg == 'logo':
        splitter = LeaveOneGroupOut()
    else:
        raise ValueError('"alg" should be one of "holdout", "kfold", "logo", or "groupk".')

    split = splitter.split(X, y, groups)

    for I_train, I_test in split:
        yield I_train, I_test


def _train(
    dir_result: str,
    name: str,
    X_train: pd.DataFrame,
    y_train: np.ndarray,
    X_test: pd.DataFrame,
    y_test: np.ndarray,
    C_cat: np.ndarray,
    C_num: np.ndarray,
    estimator: BaseEstimator,
    normalize: bool = False,
    select: Union[List[SelectFromModel], SelectFromModel] = None,
    oversample: bool = False,
    random_state: int = None,
    categories: Union[List, Dict[str, Dict[int, str]]] = None
):
    @contextmanager
    def _log(task_type: str):
        log(f'In progress: {task_type}.')
        _t = time.time()
        _err = None
        _result = dict()
        
        try:
            yield _result
        except:
            _err = tb.format_exc()
        finally:
            _e = time.time() - _t
            if _err:
                _msg = f'Failure: {task_type} ({_e:.2f}s). Keep running without this task. Caused by: \n{_err}' 
            else:
                _msg = f'Success: {task_type} ({_e:.2f}s).' 
                if _result:
                    _r = '\n'.join([f'- {k}: {v}' for k, v in _result.items()])
                    _msg = f'{_msg}\n{_r}'
            log(_msg)
    
    if normalize:
        with _log(f'[{name}] Normalizing numeric features'):
            X_train_N, X_test_N = X_train[C_num].values, X_test[C_num].values
            X_train_C, X_test_C = X_train[C_cat].values, X_test[C_cat].values
            
            scaler = StandardScaler().fit(X_train_N)
            X_train_N = scaler.transform(X_train_N)
            X_test_N = scaler.transform(X_test_N)
         
            X_train = pd.DataFrame(
                np.concatenate((X_train_C, X_train_N), axis=1),
                columns=np.concatenate((C_cat, C_num))
            )
            X_test = pd.DataFrame(
                np.concatenate((X_test_C, X_test_N), axis=1),
                columns=np.concatenate((C_cat, C_num))
            )
           
    if select:
        if isinstance(select, SelectFromModel):
            select = [select]
            
        for i, s in enumerate(select):
            with _log(f'[{name}] {i+1}-th Feature selection') as r:
                C = np.asarray(X_train.columns)
                r['# Orig. Feat.'] = f'{len(C)} (# Cat. = {len(C_cat)}; # Num. = {len(C_num)})'
                M = s.fit(X=X_train.values, y=y_train).get_support()
                C_sel = C[M]
                C_cat = C_cat[np.isin(C_cat, C_sel)]
                C_num = C_num[np.isin(C_num, C_sel)]
                
                X_train_N, X_test_N = X_train[C_num].values, X_test[C_num].values
                X_train_C, X_test_C = X_train[C_cat].values, X_test[C_cat].values


                X_train = pd.DataFrame(
                    np.concatenate((X_train_C, X_train_N), axis=1),
                    columns=np.concatenate((C_cat, C_num))
                )
                X_test = pd.DataFrame(
                    np.concatenate((X_test_C, X_test_N), axis=1),
                    columns=np.concatenate((C_cat, C_num))
                )
                r['# Sel. Feat.'] = f'{len(C_sel)} (# Cat. = {len(C_cat)}; # Num. = {len(C_num)})'

    # if oversample:
    #     with _log(f'[{name}] Oversampling') as r:
    #         if len(C_cat):
    #             M = np.isin(X_train.columns, C_cat)
    #             sampler = SMOTENC(categorical_features=M, random_state=random_state)
    #         else:
    #             sampler = SMOTE(random_state=random_state)
    #         X_train, y_train = sampler.fit_resample(X_train, y_train)

    with _log(f'[{name}] Training'):
        estimator = estimator.fit(X_train, y_train)
        result = FoldResult(
            name=name,
            estimator=estimator,
            X_train=X_train,
            y_train=y_train,
            X_test=X_test,
            y_test=y_test,
            categories=categories
        )
        dump(result, os.path.join(dir_result, f'{name}.pkl'))
    

def cross_val(
    X: pd.DataFrame,
    y: np.ndarray,
    groups: np.ndarray,
    path: str,
    name: str,
    estimator: BaseEstimator,
    categories: List[str] = None,
    normalize: bool = False,
    split: str = None,
    split_params: Dict[str, any] = None,
    select: Union[List[SelectFromModel], SelectFromModel] = None,
    oversample: bool = False,
    random_state: int = None
):
    if not os.path.exists(path):
        raise ValueError('"path" does not exist.')
    
    if not split:
        raise ValueError('"split" should be specified.')
    
    if not ray.is_initialized():
        raise EnvironmentError('"ray" should be initialized.')
    
    jobs = []
    func = ray.remote(_train).remote

    categories = list() if categories is None else categories
    C_cat = np.asarray(sorted(categories))
    C_num = np.asarray(sorted(X.columns[~X.columns.isin(C_cat)]))

    split_params = split_params or dict()
    splitter = _split(alg=split, X=X, y=y, groups=groups, random_state=random_state, **split_params)

    for idx_fold, (I_train, I_test) in enumerate(splitter):
        if split == 'logo':
            FOLD_NAME = str(np.unique(groups[I_test]).item(0))
        else:
            FOLD_NAME = str(idx_fold + 1)

        X_train, y_train = X.iloc[I_train, :], y[I_train]
        X_test, y_test = X.iloc[I_test, :], y[I_test]

        job = func(
            dir_result=path,
            name=f'{name}#{FOLD_NAME}',
            X_train=X_train,
            y_train=y_train,
            X_test=X_test,
            y_test=y_test,
            C_cat=C_cat,
            C_num=C_num,
            categories=categories,
            estimator=clone(estimator),
            normalize=normalize,
            select=select,
            oversample=oversample,
            random_state=random_state
        )
        jobs.append(job)
    ray.get(jobs)

# %% [markdown]
# ### Minor Modification on XGBClassifer
# This modification allows XGBClassifiers to automatically generate evaluation sets during pipeline (without passing any argument in "fit" function)

# %% [markdown]
# ### 참고) xgboost 공홈 주소
# - https://xgboost.readthedocs.io/en/stable/python/python_api.html#xgboost.XGBClassifier
# - https://xgboost.readthedocs.io/en/release_2.0.0/parameter.html
#
# ### 참고) RF 공홈 주소
# - https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
#
# <br> parameter 수정 시 사용

# %%
# !pip show xgboost
# Out:
# Name: xgboost
# Version: 1.7.1
# Summary: XGBoost Python Package
# Home-page: https://github.com/dmlc/xgboost
# Author:
# Author-email:
# License: Apache-2.0
# Location: /home/yeji0501/miniconda3/envs/sci-data/lib/python3.9/site-packages
# Requires: numpy, scipy
# Required-by:

# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.base import BaseEstimator
from sklearn.model_selection import StratifiedShuffleSplit
from typing import Union


class EvXGBClassifier(BaseEstimator):
    def __init__(
        self,
        # eval_size=None,
        eval_metric='logloss',
        early_stopping_rounds=10,
        random_state=None,
        **kwargs
        ):
        self.random_state = random_state
        # self.eval_size = eval_size
        self.eval_metric = eval_metric  # 수정 가능 => rmse, mae, error(=> binary classification error rate), auc 등등
        self.early_stopping_rounds = early_stopping_rounds
        self.model = XGBClassifier(
            random_state=self.random_state,
            eval_metric=self.eval_metric,
            early_stopping_rounds=self.early_stopping_rounds,
            **kwargs
        )

    @property
    def classes_(self):
        return self.model.classes_

    @property
    def feature_importances_(self):
        return self.model.feature_importances_
    
    @property
    def feature_names_in_(self):
        return self.model.feature_names_in_

    def fit(self, X: Union[pd.DataFrame, np.ndarray], y: np.ndarray):
        if self.eval_size:
            splitter = StratifiedShuffleSplit(random_state=self.random_state, test_size=self.eval_size)
            I_train, I_eval = next(splitter.split(X, y))
            if isinstance(X, pd.DataFrame):
                X_train, y_train = X.iloc[I_train, :], y[I_train]
                X_eval, y_eval = X.iloc[I_eval, :], y[I_eval]
            else:
                X_train, y_train = X[I_train, :], y[I_train]
                X_eval, y_eval = X[I_eval, :], y[I_eval]
                
            self.model = self.model.fit(
                X=X_train, y=y_train, 
                eval_set=[(X_eval, y_eval)],
                verbose=False
            )
        else:
            self.model = self.model.fit(X=X, y=y, verbose=False)
        return self

    def predict(self, X: pd.DataFrame):
        return self.model.predict(X)

    def predict_proba(self, X: pd.DataFrame):
        return self.model.predict_proba(X)

# %% [markdown]
# ## Execution

# %% [markdown]
# Unfortunately, our feature data has a big-$p$, little-$N$ problem: # sample = 2,619 while # features = 3,356.
# Therefore, we need to choose important features only.

# %%
import os
from itertools import product
from sklearn.base import clone
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.feature_selection import SelectFromModel
# from eli5.sklearn.permutation_importance import PermutationImportance

RANDOM_STATE = 42
ESTIMATOR_DUMMY = DummyClassifier(strategy='prior')
ESTIMATOR_RF = RandomForestClassifier(random_state=RANDOM_STATE) # 파라미터 수정 가능
ESTIMATOR_XGB = EvXGBClassifier(
    random_state=RANDOM_STATE, 
    eval_metric='logloss', # loss function : rmse, mae, mlogloss, merror, auc
    eval_size=0.2,
    early_stopping_rounds=10,
    # 목적 함수
    objective='binary:logistic',  
    # 1. multi:softmax: set XGBoost to do multiclass classification using the softmax objective, you also need to set num_class(number of classes)
    # 2. binary:logitraw: logistic regression for binary classification, output score before logistic transformation
    verbosity=0,
    learning_rate=0.01
)

SELECT_SVC = SelectFromModel(
    estimator=LinearSVC(
        penalty='l1',
        loss='squared_hinge',
        dual=False,
        tol=1e-3,
        C=1e-2,
        max_iter=5000,
        random_state=RANDOM_STATE
    ),
    threshold=1e-5
)

CLS = ['attention']
SETTINGS = [
    dict(
        estimator=clone(ESTIMATOR_DUMMY),
        oversample=False,
        select=None,
        name='dummy'
    ),
    dict(
        estimator=clone(ESTIMATOR_RF),
        oversample=False,
        select=[clone(SELECT_SVC)],
        name='rf_ns'
    ),
    # dict(
    #     estimator=clone(ESTIMATOR_RF),
    #     oversample=True,
    #     select=[clone(SELECT_SVC)],
    #     name='rf_os'
    # ),
    dict(
        estimator=clone(ESTIMATOR_XGB),
        oversample=False,
        select=[clone(SELECT_SVC)],
        name='xgb_ns'
    ),
    # dict(
    #     estimator=clone(ESTIMATOR_XGB),
    #     oversample=True,
    #     select=[clone(SELECT_SVC)],
    #     name='xgb_os'
    # )
]

with on_ray(num_cpus=12):
    for l, s in product(
        CLS, SETTINGS
    ):
        p = os.path.join(PATH_INTERMEDIATE, f'{l}.pkl')
        par_dir = os.path.join(PATH_INTERMEDIATE, 'eval', l)
        os.makedirs(par_dir, exist_ok=True)
        
        X, y, groups, t, datetimes = load(p)
        cats = X.columns[X.dtypes == bool]
        cross_val(
            X=X, y=y, groups=groups,
            path=par_dir,
            categories=cats,
            normalize=True,
            split='logo',
            random_state=RANDOM_STATE,
            **s
        )
# Out:
# 2025-05-21 02:28:14,736	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P05] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P05] Normalizing numeric features (0.01s).
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P05] Training.
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P06] Normalizing numeric features.
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P06] Normalizing numeric features (0.02s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P06] Training.
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P08] Normalizing numeric features.
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P08] Normalizing numeric features (0.02s).
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P08] Training.
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P09] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P09] Normalizing numeric features (0.01s).
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P09] Training.
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P07] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P07] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P07] Training.
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P12] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P12] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P12] Training.
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P10] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P10] Normalizing numeric features (0.02s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P10] Training.
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P11] Normalizing numeric features.
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P11] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P11] Training.
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P04] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P04] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P04] Training.
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P03] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P03] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P03] Training.
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P02] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P02] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P02] Training.
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P01] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P01] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P01] Training.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P01] Training (0.03s).
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P05] Training (0.07s).
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P23] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P23] Normalizing numeric features (0.01s).
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P23] Training.
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P06] Training (0.06s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P20] Normalizing numeric features.
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P20] Normalizing numeric features (0.01s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P20] Training.
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P20] Training (0.06s).
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P08] Training (0.06s).
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P22] Normalizing numeric features.
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P22] Normalizing numeric features (0.01s).
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P22] Training.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P09] Training (0.05s).
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P19] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P19] Normalizing numeric features (0.01s).
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P19] Training.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P19] Training (0.06s).
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P32] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P07] Training (0.07s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P24] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P24] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P24] Training.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P12] Training (0.04s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P16] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P16] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P16] Training.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P16] Training (0.05s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P29] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P29] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P29] Training.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P10] Training (0.05s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P17] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P17] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P17] Training.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P17] Training (0.05s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P30] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P30] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P30] Training.
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P11] Training (0.06s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P21] Normalizing numeric features.
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P21] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P21] Training.
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P21] Training (0.06s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P34] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P04] Training (0.04s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P14] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P14] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P14] Training.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P14] Training (0.04s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P26] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P26] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P26] Training.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P03] Training (0.06s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P18] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P18] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P18] Training.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P18] Training (0.05s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P31] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P31] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P31] Training.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P02] Training (0.04s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P15] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P15] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P15] Training.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P15] Training (0.05s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P28] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P28] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P28] Training.
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P13] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P13] Normalizing numeric features (0.00s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P13] Training.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P13] Training (0.05s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P25] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P25] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P25] Training.
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P23] Training (0.06s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P33] Normalizing numeric features.
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P33] Normalizing numeric features (0.01s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P33] Training.
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P22] Training (0.06s).
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P35] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P32] Normalizing numeric features (0.01s).
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P32] Training.
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P34] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P34] Training.
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P36] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P24] Training (0.05s).
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P36] Normalizing numeric features (0.01s).
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P36] Training.
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P36] Training (0.06s).
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P48] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P48] Normalizing numeric features (0.01s).
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P48] Training.
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P33] Training (0.06s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P45] Normalizing numeric features.
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P45] Normalizing numeric features (0.01s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P45] Training.
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P35] Normalizing numeric features (0.01s).
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P35] Training.
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P35] Training (0.06s).
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P47] Normalizing numeric features.
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P47] Normalizing numeric features (0.01s).
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P47] Training.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P32] Training (0.06s).
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P44] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P44] Normalizing numeric features (0.01s).
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P44] Training.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P44] Training (0.06s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P37] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P37] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P37] Training.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P37] Training (0.05s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P49] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P49] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P49] Training.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P29] Training (0.05s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P41] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P41] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P41] Training.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P41] Training (0.05s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P53] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P53] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P53] Training.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P30] Training (0.06s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P42] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P42] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P42] Training.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P42] Training (0.06s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P54] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P54] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P54] Training.
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P34] Training (0.06s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P46] Normalizing numeric features.
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P46] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P46] Training.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P26] Training (0.05s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P39] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P39] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P39] Training.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P39] Training (0.06s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P51] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P51] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P51] Training.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P31] Training (0.05s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P43] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P43] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P43] Training.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P43] Training (0.06s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P55] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P55] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:17] In progress: [dummy#P55] Training.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P28] Training (0.05s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P40] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P40] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P40] Training.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P40] Training (0.06s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P52] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P52] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P52] Training.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P25] Training (0.06s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P38] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P38] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P38] Training.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P38] Training (0.06s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P50] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P50] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P50] Training.
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P45] Training (0.06s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P57] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P56] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:17] Success: [dummy#P56] Normalizing numeric features (0.01s).
# (_train pid=11496) [25-05-21 02:28:17] In progress: [dummy#P56] Training.
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P46] Training (0.05s).
# (_train pid=11495) [25-05-21 02:28:17] Success: [dummy#P57] Normalizing numeric features (0.01s).
# (_train pid=11495) [25-05-21 02:28:17] In progress: [dummy#P57] Training.
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P47] Training (0.05s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P58] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P48] Training (0.05s).
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P61] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:17] Success: [dummy#P61] Normalizing numeric features (0.01s).
# (_train pid=11500) [25-05-21 02:28:17] In progress: [dummy#P61] Training.
# (_train pid=11500) [25-05-21 02:28:18] Success: [dummy#P61] Training (0.05s).
# (_train pid=11500) [25-05-21 02:28:18] In progress: [dummy#P75] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:18] Success: [dummy#P75] Normalizing numeric features (0.01s).
# (_train pid=11500) [25-05-21 02:28:18] In progress: [dummy#P75] Training.
# (_train pid=11495) [25-05-21 02:28:18] Success: [dummy#P57] Training (0.06s).
# (_train pid=11495) [25-05-21 02:28:18] In progress: [dummy#P72] Normalizing numeric features.
# (_train pid=11495) [25-05-21 02:28:18] Success: [dummy#P72] Normalizing numeric features (0.01s).
# (_train pid=11495) [25-05-21 02:28:18] In progress: [dummy#P72] Training.
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P60] Normalizing numeric features.
# (_train pid=11502) [25-05-21 02:28:17] Success: [dummy#P60] Normalizing numeric features (0.01s).
# (_train pid=11502) [25-05-21 02:28:17] In progress: [dummy#P60] Training.
# (_train pid=11502) [25-05-21 02:28:18] Success: [dummy#P60] Training (0.05s).
# (_train pid=11502) [25-05-21 02:28:18] In progress: [dummy#P74] Normalizing numeric features.
# (_train pid=11502) [25-05-21 02:28:18] Success: [dummy#P74] Normalizing numeric features (0.01s).
# (_train pid=11502) [25-05-21 02:28:18] In progress: [dummy#P74] Training.
# (_train pid=11496) [25-05-21 02:28:18] Success: [dummy#P56] Training (0.05s).
# (_train pid=11496) [25-05-21 02:28:18] In progress: [dummy#P70] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:18] Success: [dummy#P70] Normalizing numeric features (0.01s).
# (_train pid=11496) [25-05-21 02:28:18] In progress: [dummy#P70] Training.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P49] Training (0.05s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P62] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:17] Success: [dummy#P62] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:17] In progress: [dummy#P62] Training.
# (_train pid=11504) [25-05-21 02:28:18] Success: [dummy#P62] Training (0.06s).
# (_train pid=11504) [25-05-21 02:28:18] In progress: [dummy#P76] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:18] Success: [dummy#P76] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:18] In progress: [dummy#P76] Training.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P53] Training (0.05s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P67] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:17] Success: [dummy#P67] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:17] In progress: [dummy#P67] Training.
# (_train pid=11494) [25-05-21 02:28:18] Success: [dummy#P67] Training (0.05s).
# (_train pid=11494) [25-05-21 02:28:18] In progress: [dummy#P80] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:17] Success: [dummy#P54] Training (0.06s).
# (_train pid=11498) [25-05-21 02:28:17] In progress: [dummy#P68] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:18] Success: [dummy#P68] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:18] In progress: [dummy#P68] Training.
# (_train pid=11498) [25-05-21 02:28:18] Success: [dummy#P68] Training (0.05s).
# (_train pid=11497) [25-05-21 02:28:17] Success: [dummy#P58] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:17] In progress: [dummy#P58] Training.
# (_train pid=11497) [25-05-21 02:28:18] Success: [dummy#P58] Training (0.06s).
# (_train pid=11497) [25-05-21 02:28:18] In progress: [dummy#P73] Normalizing numeric features.
# (_train pid=11497) [25-05-21 02:28:18] Success: [dummy#P73] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:18] In progress: [dummy#P73] Training.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P51] Training (0.05s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P64] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:17] Success: [dummy#P64] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:17] In progress: [dummy#P64] Training.
# (_train pid=11501) [25-05-21 02:28:18] Success: [dummy#P64] Training (0.06s).
# (_train pid=11501) [25-05-21 02:28:18] In progress: [dummy#P78] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:18] Success: [dummy#P78] Normalizing numeric features (0.00s).
# (_train pid=11501) [25-05-21 02:28:18] In progress: [dummy#P78] Training.
# (_train pid=11503) [25-05-21 02:28:17] Success: [dummy#P55] Training (0.05s).
# (_train pid=11503) [25-05-21 02:28:18] In progress: [dummy#P69] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:18] Success: [dummy#P69] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:18] In progress: [dummy#P69] Training.
# (_train pid=11503) [25-05-21 02:28:18] Success: [dummy#P69] Training (0.05s).
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P52] Training (0.06s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P66] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:17] Success: [dummy#P66] Normalizing numeric features (0.00s).
# (_train pid=11493) [25-05-21 02:28:17] In progress: [dummy#P66] Training.
# (_train pid=11493) [25-05-21 02:28:18] Success: [dummy#P66] Training (0.06s).
# (_train pid=11493) [25-05-21 02:28:18] In progress: [dummy#P79] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:18] Success: [dummy#P79] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:18] In progress: [dummy#P79] Training.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P50] Training (0.05s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P63] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:17] Success: [dummy#P63] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:17] In progress: [dummy#P63] Training.
# (_train pid=11499) [25-05-21 02:28:18] Success: [dummy#P63] Training (0.06s).
# (_train pid=11499) [25-05-21 02:28:18] In progress: [dummy#P77] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:18] Success: [dummy#P77] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:18] In progress: [dummy#P77] Training.
# (_train pid=11496) [25-05-21 02:28:18] Success: [dummy#P70] Training (0.05s).
# (_train pid=11494) [25-05-21 02:28:18] Success: [dummy#P80] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:18] In progress: [dummy#P80] Training.
# (_train pid=11500) [25-05-21 02:28:18] Success: [dummy#P75] Training (0.06s).
# (_train pid=11495) [25-05-21 02:28:18] Success: [dummy#P72] Training (0.06s).
# (_train pid=11502) [25-05-21 02:28:18] Success: [dummy#P74] Training (0.06s).
# (_train pid=11504) [25-05-21 02:28:18] Success: [dummy#P76] Training (0.05s).
# (_train pid=11494) [25-05-21 02:28:18] Success: [dummy#P80] Training (0.05s).
# (_train pid=11497) [25-05-21 02:28:18] Success: [dummy#P73] Training (0.05s).
# (_train pid=11501) [25-05-21 02:28:18] Success: [dummy#P78] Training (0.06s).
# (_train pid=11493) [25-05-21 02:28:18] Success: [dummy#P79] Training (0.05s).
# (_train pid=11499) [25-05-21 02:28:18] Success: [dummy#P77] Training (0.06s).
# (_train pid=11500) [25-05-21 02:28:18] In progress: [rf_ns#P06] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:18] Success: [rf_ns#P06] Normalizing numeric features (0.01s).
# (_train pid=11500) [25-05-21 02:28:18] In progress: [rf_ns#P06] 1-th Feature selection.
# (_train pid=11500) [25-05-21 02:28:18] Success: [rf_ns#P06] 1-th Feature selection (0.02s).
# (_train pid=11500) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11500) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11500) [25-05-21 02:28:18] In progress: [rf_ns#P06] Training.
# (_train pid=11495) [25-05-21 02:28:18] In progress: [rf_ns#P09] Normalizing numeric features.
# (_train pid=11495) [25-05-21 02:28:18] Success: [rf_ns#P09] Normalizing numeric features (0.01s).
# (_train pid=11495) [25-05-21 02:28:18] In progress: [rf_ns#P09] 1-th Feature selection.
# (_train pid=11502) [25-05-21 02:28:18] In progress: [rf_ns#P07] Normalizing numeric features.
# (_train pid=11502) [25-05-21 02:28:18] Success: [rf_ns#P07] Normalizing numeric features (0.02s).
# (_train pid=11502) [25-05-21 02:28:18] In progress: [rf_ns#P07] 1-th Feature selection.
# (_train pid=11496) [25-05-21 02:28:18] In progress: [rf_ns#P10] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:18] Success: [rf_ns#P10] Normalizing numeric features (0.01s).
# (_train pid=11496) [25-05-21 02:28:18] In progress: [rf_ns#P10] 1-th Feature selection.
# (_train pid=11504) [25-05-21 02:28:18] In progress: [rf_ns#P05] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:18] Success: [rf_ns#P05] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:18] In progress: [rf_ns#P05] 1-th Feature selection.
# (_train pid=11504) [25-05-21 02:28:18] Success: [rf_ns#P05] 1-th Feature selection (0.03s).
# (_train pid=11504) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11504) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11504) [25-05-21 02:28:18] In progress: [rf_ns#P05] Training.
# (_train pid=11494) [25-05-21 02:28:18] In progress: [rf_ns#P01] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:18] Success: [rf_ns#P01] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:18] In progress: [rf_ns#P01] 1-th Feature selection.
# (_train pid=11494) [25-05-21 02:28:18] Success: [rf_ns#P01] 1-th Feature selection (0.03s).
# (_train pid=11494) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11494) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11494) [25-05-21 02:28:18] In progress: [rf_ns#P01] Training.
# (_train pid=11498) [25-05-21 02:28:18] In progress: [rf_ns#P12] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:18] Success: [rf_ns#P12] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:18] In progress: [rf_ns#P12] 1-th Feature selection.
# (_train pid=11497) [25-05-21 02:28:18] In progress: [rf_ns#P08] Normalizing numeric features.
# (_train pid=11497) [25-05-21 02:28:18] Success: [rf_ns#P08] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:18] In progress: [rf_ns#P08] 1-th Feature selection.
# (_train pid=11501) [25-05-21 02:28:18] In progress: [rf_ns#P03] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:18] Success: [rf_ns#P03] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:18] In progress: [rf_ns#P03] 1-th Feature selection.
# (_train pid=11501) [25-05-21 02:28:18] Success: [rf_ns#P03] 1-th Feature selection (0.02s).
# (_train pid=11501) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11501) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11501) [25-05-21 02:28:18] In progress: [rf_ns#P03] Training.
# (_train pid=11503) [25-05-21 02:28:18] In progress: [rf_ns#P11] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:18] Success: [rf_ns#P11] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:18] In progress: [rf_ns#P11] 1-th Feature selection.
# (_train pid=11493) [25-05-21 02:28:18] In progress: [rf_ns#P02] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:18] Success: [rf_ns#P02] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:18] In progress: [rf_ns#P02] 1-th Feature selection.
# (_train pid=11493) [25-05-21 02:28:18] Success: [rf_ns#P02] 1-th Feature selection (0.03s).
# (_train pid=11493) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11493) - # Sel. Feat.: 13 (# Cat. = 0; # Num. = 13)
# (_train pid=11493) [25-05-21 02:28:18] In progress: [rf_ns#P02] Training.
# (_train pid=11499) [25-05-21 02:28:18] In progress: [rf_ns#P04] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:18] Success: [rf_ns#P04] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:18] In progress: [rf_ns#P04] 1-th Feature selection.
# (_train pid=11499) [25-05-21 02:28:18] Success: [rf_ns#P04] 1-th Feature selection (0.02s).
# (_train pid=11499) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11499) - # Sel. Feat.: 14 (# Cat. = 1; # Num. = 13)
# (_train pid=11499) [25-05-21 02:28:18] In progress: [rf_ns#P04] Training.
# (_train pid=11502) [25-05-21 02:28:18] Success: [rf_ns#P07] 1-th Feature selection (0.03s).
# (_train pid=11502) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11502) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11502) [25-05-21 02:28:18] In progress: [rf_ns#P07] Training.
# (_train pid=11497) [25-05-21 02:28:18] Success: [rf_ns#P08] 1-th Feature selection (0.03s).
# (_train pid=11497) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11497) - # Sel. Feat.: 17 (# Cat. = 0; # Num. = 17)
# (_train pid=11497) [25-05-21 02:28:18] In progress: [rf_ns#P08] Training.
# (_train pid=11495) [25-05-21 02:28:18] Success: [rf_ns#P09] 1-th Feature selection (0.03s).
# (_train pid=11495) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11495) - # Sel. Feat.: 13 (# Cat. = 0; # Num. = 13)
# (_train pid=11495) [25-05-21 02:28:18] In progress: [rf_ns#P09] Training.
# (_train pid=11496) [25-05-21 02:28:18] Success: [rf_ns#P10] 1-th Feature selection (0.03s).
# (_train pid=11496) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11496) - # Sel. Feat.: 12 (# Cat. = 0; # Num. = 12)
# (_train pid=11496) [25-05-21 02:28:18] In progress: [rf_ns#P10] Training.
# (_train pid=11498) [25-05-21 02:28:18] Success: [rf_ns#P12] 1-th Feature selection (0.02s).
# (_train pid=11498) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11498) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11498) [25-05-21 02:28:18] In progress: [rf_ns#P12] Training.
# (_train pid=11503) [25-05-21 02:28:18] Success: [rf_ns#P11] 1-th Feature selection (0.02s).
# (_train pid=11503) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11503) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11503) [25-05-21 02:28:18] In progress: [rf_ns#P11] Training.
# (_train pid=11493) [25-05-21 02:28:19] Success: [rf_ns#P02] Training (1.53s).
# (_train pid=11493) [25-05-21 02:28:19] In progress: [rf_ns#P13] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:19] Success: [rf_ns#P13] Normalizing numeric features (0.00s).
# (_train pid=11493) [25-05-21 02:28:19] In progress: [rf_ns#P13] 1-th Feature selection.
# (_train pid=11493) [25-05-21 02:28:19] Success: [rf_ns#P13] 1-th Feature selection (0.02s).
# (_train pid=11493) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11493) - # Sel. Feat.: 17 (# Cat. = 1; # Num. = 16)
# (_train pid=11493) [25-05-21 02:28:19] In progress: [rf_ns#P13] Training.
# (_train pid=11499) [25-05-21 02:28:19] Success: [rf_ns#P04] Training (1.52s).
# (_train pid=11499) [25-05-21 02:28:19] In progress: [rf_ns#P14] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:19] Success: [rf_ns#P14] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:19] In progress: [rf_ns#P14] 1-th Feature selection.
# (_train pid=11499) [25-05-21 02:28:19] Success: [rf_ns#P14] 1-th Feature selection (0.01s).
# (_train pid=11499) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11499) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11499) [25-05-21 02:28:19] In progress: [rf_ns#P14] Training.
# (_train pid=11500) [25-05-21 02:28:19] Success: [rf_ns#P06] Training (1.61s).
# (_train pid=11500) [25-05-21 02:28:19] In progress: [rf_ns#P16] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:19] Success: [rf_ns#P16] Normalizing numeric features (0.00s).
# (_train pid=11500) [25-05-21 02:28:19] In progress: [rf_ns#P16] 1-th Feature selection.
# (_train pid=11500) [25-05-21 02:28:19] Success: [rf_ns#P16] 1-th Feature selection (0.02s).
# (_train pid=11500) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11500) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11500) [25-05-21 02:28:19] In progress: [rf_ns#P16] Training.
# (_train pid=11504) [25-05-21 02:28:19] Success: [rf_ns#P05] Training (1.63s).
# (_train pid=11504) [25-05-21 02:28:19] In progress: [rf_ns#P17] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:19] Success: [rf_ns#P17] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:19] In progress: [rf_ns#P17] 1-th Feature selection.
# (_train pid=11504) [25-05-21 02:28:19] Success: [rf_ns#P17] 1-th Feature selection (0.01s).
# (_train pid=11504) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11504) - # Sel. Feat.: 13 (# Cat. = 0; # Num. = 13)
# (_train pid=11504) [25-05-21 02:28:19] In progress: [rf_ns#P17] Training.
# (_train pid=11498) [25-05-21 02:28:19] Success: [rf_ns#P12] Training (1.61s).
# (_train pid=11498) [25-05-21 02:28:19] In progress: [rf_ns#P18] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:19] Success: [rf_ns#P18] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:19] In progress: [rf_ns#P18] 1-th Feature selection.
# (_train pid=11501) [25-05-21 02:28:19] Success: [rf_ns#P03] Training (1.63s).
# (_train pid=11501) [25-05-21 02:28:19] In progress: [rf_ns#P15] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:19] Success: [rf_ns#P15] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:19] In progress: [rf_ns#P15] 1-th Feature selection.
# (_train pid=11501) [25-05-21 02:28:19] Success: [rf_ns#P15] 1-th Feature selection (0.01s).
# (_train pid=11501) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11501) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11501) [25-05-21 02:28:19] In progress: [rf_ns#P15] Training.
# (_train pid=11503) [25-05-21 02:28:19] Success: [rf_ns#P11] Training (1.63s).
# (_train pid=11495) [25-05-21 02:28:19] Success: [rf_ns#P09] Training (1.66s).
# (_train pid=11495) [25-05-21 02:28:19] In progress: [rf_ns#P23] Normalizing numeric features.
# (_train pid=11495) [25-05-21 02:28:19] Success: [rf_ns#P23] Normalizing numeric features (0.01s).
# (_train pid=11495) [25-05-21 02:28:19] In progress: [rf_ns#P23] 1-th Feature selection.
# (_train pid=11495) [25-05-21 02:28:19] Success: [rf_ns#P23] 1-th Feature selection (0.02s).
# (_train pid=11495) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11495) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11495) [25-05-21 02:28:19] In progress: [rf_ns#P23] Training.
# (_train pid=11502) [25-05-21 02:28:19] Success: [rf_ns#P07] Training (1.65s).
# (_train pid=11502) [25-05-21 02:28:19] In progress: [rf_ns#P22] Normalizing numeric features.
# (_train pid=11502) [25-05-21 02:28:19] Success: [rf_ns#P22] Normalizing numeric features (0.01s).
# (_train pid=11502) [25-05-21 02:28:19] In progress: [rf_ns#P22] 1-th Feature selection.
# (_train pid=11502) [25-05-21 02:28:19] Success: [rf_ns#P22] 1-th Feature selection (0.02s).
# (_train pid=11502) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11502) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11502) [25-05-21 02:28:19] In progress: [rf_ns#P22] Training.
# (_train pid=11496) [25-05-21 02:28:19] Success: [rf_ns#P10] Training (1.64s).
# (_train pid=11496) [25-05-21 02:28:19] In progress: [rf_ns#P21] Normalizing numeric features.
# (_train pid=11496) [25-05-21 02:28:19] Success: [rf_ns#P21] Normalizing numeric features (0.01s).
# (_train pid=11496) [25-05-21 02:28:19] In progress: [rf_ns#P21] 1-th Feature selection.
# (_train pid=11496) [25-05-21 02:28:19] Success: [rf_ns#P21] 1-th Feature selection (0.03s).
# (_train pid=11496) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11496) - # Sel. Feat.: 16 (# Cat. = 0; # Num. = 16)
# (_train pid=11496) [25-05-21 02:28:19] In progress: [rf_ns#P21] Training.
# (_train pid=11494) [25-05-21 02:28:19] Success: [rf_ns#P01] Training (1.71s).
# (_train pid=11494) [25-05-21 02:28:19] In progress: [rf_ns#P20] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:19] Success: [rf_ns#P20] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:19] In progress: [rf_ns#P20] 1-th Feature selection.
# (_train pid=11494) [25-05-21 02:28:19] Success: [rf_ns#P20] 1-th Feature selection (0.02s).
# (_train pid=11494) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11494) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11494) [25-05-21 02:28:19] In progress: [rf_ns#P20] Training.
# (_train pid=11498) [25-05-21 02:28:19] Success: [rf_ns#P18] 1-th Feature selection (0.01s).
# (_train pid=11498) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11498) - # Sel. Feat.: 13 (# Cat. = 1; # Num. = 12)
# (_train pid=11498) [25-05-21 02:28:19] In progress: [rf_ns#P18] Training.
# (_train pid=11497) [25-05-21 02:28:20] Success: [rf_ns#P08] Training (1.71s).
# (_train pid=11497) [25-05-21 02:28:20] In progress: [rf_ns#P24] Normalizing numeric features.
# (_train pid=11497) [25-05-21 02:28:20] Success: [rf_ns#P24] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:20] In progress: [rf_ns#P24] 1-th Feature selection.
# (_train pid=11497) [25-05-21 02:28:20] Success: [rf_ns#P24] 1-th Feature selection (0.02s).
# (_train pid=11497) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11497) - # Sel. Feat.: 13 (# Cat. = 0; # Num. = 13)
# (_train pid=11497) [25-05-21 02:28:20] In progress: [rf_ns#P24] Training.
# (_train pid=11503) [25-05-21 02:28:19] In progress: [rf_ns#P19] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:19] Success: [rf_ns#P19] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:19] In progress: [rf_ns#P19] 1-th Feature selection.
# (_train pid=11503) [25-05-21 02:28:19] Success: [rf_ns#P19] 1-th Feature selection (0.02s).
# (_train pid=11503) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11503) - # Sel. Feat.: 15 (# Cat. = 1; # Num. = 14)
# (_train pid=11503) [25-05-21 02:28:19] In progress: [rf_ns#P19] Training.
# (_train pid=11499) [25-05-21 02:28:20] Success: [rf_ns#P14] Training (1.17s).
# (_train pid=11499) [25-05-21 02:28:20] In progress: [rf_ns#P25] Normalizing numeric features.
# (_train pid=11499) [25-05-21 02:28:20] Success: [rf_ns#P25] Normalizing numeric features (0.01s).
# (_train pid=11499) [25-05-21 02:28:20] In progress: [rf_ns#P25] 1-th Feature selection.
# (_train pid=11499) [25-05-21 02:28:21] Success: [rf_ns#P25] 1-th Feature selection (0.02s).
# (_train pid=11499) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11499) - # Sel. Feat.: 15 (# Cat. = 1; # Num. = 14)
# (_train pid=11499) [25-05-21 02:28:21] In progress: [rf_ns#P25] Training.
# (_train pid=11498) [25-05-21 02:28:21] Success: [rf_ns#P18] Training (1.31s).
# (_train pid=11498) [25-05-21 02:28:21] In progress: [rf_ns#P26] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:21] Success: [rf_ns#P17] Training (1.38s).
# (_train pid=11504) [25-05-21 02:28:21] In progress: [rf_ns#P29] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:21] Success: [rf_ns#P29] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:21] In progress: [rf_ns#P29] 1-th Feature selection.
# (_train pid=11504) [25-05-21 02:28:21] Success: [rf_ns#P29] 1-th Feature selection (0.01s).
# (_train pid=11504) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11504) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11504) [25-05-21 02:28:21] In progress: [rf_ns#P29] Training.
# (_train pid=11498) [25-05-21 02:28:21] Success: [rf_ns#P26] Normalizing numeric features (0.00s).
# (_train pid=11498) [25-05-21 02:28:21] In progress: [rf_ns#P26] 1-th Feature selection.
# (_train pid=11498) [25-05-21 02:28:21] Success: [rf_ns#P26] 1-th Feature selection (0.01s).
# (_train pid=11498) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11498) - # Sel. Feat.: 13 (# Cat. = 0; # Num. = 13)
# (_train pid=11498) [25-05-21 02:28:21] In progress: [rf_ns#P26] Training.
# (_train pid=11501) [25-05-21 02:28:21] Success: [rf_ns#P15] Training (1.40s).
# (_train pid=11501) [25-05-21 02:28:21] In progress: [rf_ns#P28] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:21] Success: [rf_ns#P28] Normalizing numeric features (0.00s).
# (_train pid=11501) [25-05-21 02:28:21] In progress: [rf_ns#P28] 1-th Feature selection.
# (_train pid=11501) [25-05-21 02:28:21] Success: [rf_ns#P28] 1-th Feature selection (0.01s).
# (_train pid=11501) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11501) - # Sel. Feat.: 14 (# Cat. = 1; # Num. = 13)
# (_train pid=11501) [25-05-21 02:28:21] In progress: [rf_ns#P28] Training.
# (_train pid=11500) [25-05-21 02:28:21] Success: [rf_ns#P16] Training (1.45s).
# (_train pid=11500) [25-05-21 02:28:21] In progress: [rf_ns#P30] Normalizing numeric features.
# (_train pid=11500) [25-05-21 02:28:21] Success: [rf_ns#P30] Normalizing numeric features (0.00s).
# (_train pid=11500) [25-05-21 02:28:21] In progress: [rf_ns#P30] 1-th Feature selection.
# (_train pid=11500) [25-05-21 02:28:21] Success: [rf_ns#P30] 1-th Feature selection (0.01s).
# (_train pid=11500) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11500) - # Sel. Feat.: 16 (# Cat. = 1; # Num. = 15)
# (_train pid=11500) [25-05-21 02:28:21] In progress: [rf_ns#P30] Training.
# (_train pid=11495) [25-05-21 02:28:21] Success: [rf_ns#P23] Training (1.40s).
# (_train pid=11495) [25-05-21 02:28:21] In progress: [rf_ns#P32] Normalizing numeric features.
# (_train pid=11495) [25-05-21 02:28:21] Success: [rf_ns#P32] Normalizing numeric features (0.01s).
# (_train pid=11495) [25-05-21 02:28:21] In progress: [rf_ns#P32] 1-th Feature selection.
# (_train pid=11495) [25-05-21 02:28:21] Success: [rf_ns#P32] 1-th Feature selection (0.02s).
# (_train pid=11495) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11495) - # Sel. Feat.: 16 (# Cat. = 1; # Num. = 15)
# (_train pid=11495) [25-05-21 02:28:21] In progress: [rf_ns#P32] Training.
# (_train pid=11502) [25-05-21 02:28:21] Success: [rf_ns#P22] Training (1.42s).
# (_train pid=11502) [25-05-21 02:28:21] In progress: [rf_ns#P33] Normalizing numeric features.
# (_train pid=11502) [25-05-21 02:28:21] Success: [rf_ns#P33] Normalizing numeric features (0.01s).
# (_train pid=11502) [25-05-21 02:28:21] In progress: [rf_ns#P33] 1-th Feature selection.
# (_train pid=11502) [25-05-21 02:28:21] Success: [rf_ns#P33] 1-th Feature selection (0.02s).
# (_train pid=11502) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11502) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11502) [25-05-21 02:28:21] In progress: [rf_ns#P33] Training.
# (_train pid=11494) [25-05-21 02:28:21] Success: [rf_ns#P20] Training (1.45s).
# (_train pid=11494) [25-05-21 02:28:21] In progress: [rf_ns#P35] Normalizing numeric features.
# (_train pid=11494) [25-05-21 02:28:21] Success: [rf_ns#P35] Normalizing numeric features (0.01s).
# (_train pid=11494) [25-05-21 02:28:21] In progress: [rf_ns#P35] 1-th Feature selection.
# (_train pid=11497) [25-05-21 02:28:21] Success: [rf_ns#P24] Training (1.39s).
# (_train pid=11497) [25-05-21 02:28:21] In progress: [rf_ns#P36] Normalizing numeric features.
# (_train pid=11497) [25-05-21 02:28:21] Success: [rf_ns#P36] Normalizing numeric features (0.01s).
# (_train pid=11497) [25-05-21 02:28:21] In progress: [rf_ns#P36] 1-th Feature selection.
# (_train pid=11497) [25-05-21 02:28:21] Success: [rf_ns#P36] 1-th Feature selection (0.02s).
# (_train pid=11497) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11497) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11497) [25-05-21 02:28:21] In progress: [rf_ns#P36] Training.
# (_train pid=11503) [25-05-21 02:28:21] Success: [rf_ns#P19] Training (1.44s).
# (_train pid=11503) [25-05-21 02:28:21] In progress: [rf_ns#P34] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:21] Success: [rf_ns#P34] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:21] In progress: [rf_ns#P34] 1-th Feature selection.
# (_train pid=11503) [25-05-21 02:28:21] Success: [rf_ns#P34] 1-th Feature selection (0.02s).
# (_train pid=11503) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11503) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11503) [25-05-21 02:28:21] In progress: [rf_ns#P34] Training.
# (_train pid=11493) [25-05-21 02:28:21] Success: [rf_ns#P13] Training (1.59s).
# (_train pid=11493) [25-05-21 02:28:21] In progress: [rf_ns#P31] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:21] Success: [rf_ns#P31] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:21] In progress: [rf_ns#P31] 1-th Feature selection.
# (_train pid=11493) [25-05-21 02:28:21] Success: [rf_ns#P31] 1-th Feature selection (0.02s).
# (_train pid=11493) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11493) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11493) [25-05-21 02:28:21] In progress: [rf_ns#P31] Training.
# (_train pid=11496) [25-05-21 02:28:21] Success: [rf_ns#P21] Training (1.49s).
# ...
# (_train pid=11504)
# (_train pid=11504) [25-05-21 02:28:28] In progress: [xgb_ns#P52] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:28] Success: [xgb_ns#P52] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:28] In progress: [xgb_ns#P52] 1-th Feature selection.
# (_train pid=11504) [25-05-21 02:28:28] Success: [xgb_ns#P52] 1-th Feature selection (0.02s).
# (_train pid=11504) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11504) - # Sel. Feat.: 17 (# Cat. = 1; # Num. = 16)
# (_train pid=11504) [25-05-21 02:28:28] In progress: [xgb_ns#P52] Training.
# (_train pid=11504) [25-05-21 02:28:28] Failure: [xgb_ns#P52] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11504) Traceback (most recent call last):
# (_train pid=11504)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11504)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11504)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11504) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11504)
# (_train pid=11504) [25-05-21 02:28:28] In progress: [xgb_ns#P58] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:28] Success: [xgb_ns#P58] Normalizing numeric features (0.01s).
# (_train pid=11504) [25-05-21 02:28:28] In progress: [xgb_ns#P58] 1-th Feature selection.
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P49] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:28] Success: [xgb_ns#P49] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P49] 1-th Feature selection.
# (_train pid=11498) [25-05-21 02:28:28] Success: [xgb_ns#P49] 1-th Feature selection (0.02s).
# (_train pid=11498) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11498) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P49] Training.
# (_train pid=11498) [25-05-21 02:28:28] Failure: [xgb_ns#P49] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11498) Traceback (most recent call last):
# (_train pid=11498)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11498)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11498)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11498) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11498)
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P55] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:28] Success: [xgb_ns#P55] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P55] 1-th Feature selection.
# (_train pid=11498) [25-05-21 02:28:28] Success: [xgb_ns#P55] 1-th Feature selection (0.01s).
# (_train pid=11498) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11498) - # Sel. Feat.: 13 (# Cat. = 0; # Num. = 13)
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P55] Training.
# (_train pid=11498) [25-05-21 02:28:28] Failure: [xgb_ns#P55] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11498) Traceback (most recent call last):
# (_train pid=11498)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11498)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11498)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11498) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11498)
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P61] Normalizing numeric features.
# (_train pid=11498) [25-05-21 02:28:28] Success: [xgb_ns#P61] Normalizing numeric features (0.01s).
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P61] 1-th Feature selection.
# (_train pid=11501) [25-05-21 02:28:28] Success: [xgb_ns#P43] 1-th Feature selection (0.02s).
# (_train pid=11501) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11501) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P43] Training.
# (_train pid=11501) [25-05-21 02:28:28] Failure: [xgb_ns#P43] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11501) Traceback (most recent call last):
# (_train pid=11501)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11501)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11501)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11501) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11501)
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P48] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:28] Success: [xgb_ns#P48] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P48] 1-th Feature selection.
# (_train pid=11501) [25-05-21 02:28:28] Success: [xgb_ns#P48] 1-th Feature selection (0.02s).
# (_train pid=11501) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11501) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P48] Training.
# (_train pid=11501) [25-05-21 02:28:28] Failure: [xgb_ns#P48] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11501) Traceback (most recent call last):
# (_train pid=11501)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11501)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11501)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11501) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11501)
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P54] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:28] Success: [xgb_ns#P54] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P54] 1-th Feature selection.
# (_train pid=11501) [25-05-21 02:28:28] Success: [xgb_ns#P54] 1-th Feature selection (0.01s).
# (_train pid=11501) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11501) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P54] Training.
# (_train pid=11501) [25-05-21 02:28:28] Failure: [xgb_ns#P54] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11501) Traceback (most recent call last):
# (_train pid=11501)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11501)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11501)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11501) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11501)
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P60] Normalizing numeric features.
# (_train pid=11501) [25-05-21 02:28:28] Success: [xgb_ns#P60] Normalizing numeric features (0.01s).
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P60] 1-th Feature selection.
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P45] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:28] Success: [xgb_ns#P45] Normalizing numeric features (0.00s).
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P45] 1-th Feature selection.
# (_train pid=11503) [25-05-21 02:28:28] Success: [xgb_ns#P45] 1-th Feature selection (0.02s).
# (_train pid=11503) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11503) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P45] Training.
# (_train pid=11503) [25-05-21 02:28:28] Failure: [xgb_ns#P45] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11503) Traceback (most recent call last):
# (_train pid=11503)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11503)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11503)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11503) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11503)
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P50] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:28] Success: [xgb_ns#P50] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P50] 1-th Feature selection.
# (_train pid=11503) [25-05-21 02:28:28] Success: [xgb_ns#P50] 1-th Feature selection (0.02s).
# (_train pid=11503) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11503) - # Sel. Feat.: 17 (# Cat. = 0; # Num. = 17)
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P50] Training.
# (_train pid=11503) [25-05-21 02:28:28] Failure: [xgb_ns#P50] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11503) Traceback (most recent call last):
# (_train pid=11503)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11503)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11503)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11503) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11503)
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P56] Normalizing numeric features.
# (_train pid=11503) [25-05-21 02:28:28] Success: [xgb_ns#P56] Normalizing numeric features (0.00s).
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P56] 1-th Feature selection.
# (_train pid=11503) [25-05-21 02:28:28] Success: [xgb_ns#P56] 1-th Feature selection (0.01s).
# (_train pid=11503) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11503) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P56] Training.
# (_train pid=11503) [25-05-21 02:28:28] Failure: [xgb_ns#P56] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11503) Traceback (most recent call last):
# (_train pid=11503)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11503)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11503)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11503) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11503)
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P62] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:28] In progress: [xgb_ns#P47] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:28] Success: [xgb_ns#P47] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:28] In progress: [xgb_ns#P47] 1-th Feature selection.
# (_train pid=11493) [25-05-21 02:28:28] Success: [xgb_ns#P47] 1-th Feature selection (0.02s).
# (_train pid=11493) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11493) - # Sel. Feat.: 14 (# Cat. = 0; # Num. = 14)
# (_train pid=11493) [25-05-21 02:28:28] In progress: [xgb_ns#P47] Training.
# (_train pid=11493) [25-05-21 02:28:28] Failure: [xgb_ns#P47] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11493) Traceback (most recent call last):
# (_train pid=11493)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11493)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11493)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11493) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11493)
# (_train pid=11493) [25-05-21 02:28:28] In progress: [xgb_ns#P53] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:28] Success: [xgb_ns#P53] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:28] In progress: [xgb_ns#P53] 1-th Feature selection.
# (_train pid=11493) [25-05-21 02:28:28] Success: [xgb_ns#P53] 1-th Feature selection (0.02s).
# (_train pid=11493) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11493) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11493) [25-05-21 02:28:28] In progress: [xgb_ns#P53] Training.
# (_train pid=11493) [25-05-21 02:28:28] Failure: [xgb_ns#P53] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11493) Traceback (most recent call last):
# (_train pid=11493)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11493)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11493)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11493) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11493)
# (_train pid=11493) [25-05-21 02:28:28] In progress: [xgb_ns#P63] Normalizing numeric features.
# (_train pid=11493) [25-05-21 02:28:28] Success: [xgb_ns#P63] Normalizing numeric features (0.01s).
# (_train pid=11493) [25-05-21 02:28:28] In progress: [xgb_ns#P63] 1-th Feature selection.
# (_train pid=11500) [25-05-21 02:28:28] In progress: [xgb_ns#P64] Normalizing numeric features.
# (_train pid=11504) [25-05-21 02:28:28] Success: [xgb_ns#P58] 1-th Feature selection (0.02s).
# (_train pid=11504) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11504) - # Sel. Feat.: 15 (# Cat. = 0; # Num. = 15)
# (_train pid=11504) [25-05-21 02:28:28] In progress: [xgb_ns#P58] Training.
# (_train pid=11504) [25-05-21 02:28:28] Failure: [xgb_ns#P58] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11504) Traceback (most recent call last):
# (_train pid=11504)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11504)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11504)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11504) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11504)
# (_train pid=11498) [25-05-21 02:28:28] Success: [xgb_ns#P61] 1-th Feature selection (0.01s).
# (_train pid=11498) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11498) - # Sel. Feat.: 11 (# Cat. = 0; # Num. = 11)
# (_train pid=11498) [25-05-21 02:28:28] In progress: [xgb_ns#P61] Training.
# (_train pid=11498) [25-05-21 02:28:28] Failure: [xgb_ns#P61] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11498) Traceback (most recent call last):
# (_train pid=11498)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11498)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11498)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11498) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11498)
# (_train pid=11501) [25-05-21 02:28:28] Success: [xgb_ns#P60] 1-th Feature selection (0.01s).
# (_train pid=11501) - # Orig. Feat.: 84 (# Cat. = 16; # Num. = 68)
# (_train pid=11501) - # Sel. Feat.: 13 (# Cat. = 1; # Num. = 12)
# (_train pid=11501) [25-05-21 02:28:28] In progress: [xgb_ns#P60] Training.
# (_train pid=11501) [25-05-21 02:28:28] Failure: [xgb_ns#P60] Training (0.00s). Keep running without this task. Caused by:
# (_train pid=11501) Traceback (most recent call last):
# (_train pid=11501)   File "/tmp/ipykernel_3766/1588096472.py", line 92, in _log
# (_train pid=11501)   File "/tmp/ipykernel_3766/1588096472.py", line 161, in _train
# (_train pid=11501)   File "/tmp/ipykernel_3766/3543046087.py", line 42, in fit
# (_train pid=11501) AttributeError: 'EvXGBClassifier' object has no attribute 'eval_size'
# (_train pid=11501)
# (_train pid=11503) [25-05-21 02:28:28] Success: [xgb_ns#P62] Normalizing numeric features (0.01s).
# (_train pid=11503) [25-05-21 02:28:28] In progress: [xgb_ns#P62] 1-th Feature selection.

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Implementation

# %%
import numpy as np
from typing import Dict
from itertools import product
from sklearn.metrics import log_loss
from sklearn.metrics import accuracy_score, balanced_accuracy_score, \
    confusion_matrix, precision_recall_fscore_support, \
    roc_auc_score, matthews_corrcoef, average_precision_score, \
    log_loss, brier_score_loss
import scipy.stats.mstats as ms


def evaluate(
    y_true: np.ndarray,
    y_pred: np.ndarray,
    y_proba: np.ndarray,
    classes: np.ndarray
) -> Dict[str, any]:
    R = {}
    n_classes = len(classes)
    is_multiclass = n_classes > 2
    is_same_y = len(np.unique(y_true)) == 1
    R['inst'] = len(y_true)
    
    for c in classes:
        R[f'inst_{c}'] = np.sum(y_true == c)
        
    if not is_multiclass:
        _, cnt = np.unique(y_true, return_counts=True)
        
        if len(cnt) > 1:
            R['class_ratio'] = cnt[0] / cnt[1]
        else:
            R['class_ratio'] = np.nan

    C = confusion_matrix(y_true=y_true, y_pred=y_pred, labels=classes)
    for (i1, c1), (i2, c2) in product(enumerate(classes), enumerate(classes)):
        R[f'true_{c1}_pred_{c2}'] = C[i1, i2]

    # Threshold Measure
    R['acc'] = accuracy_score(y_true=y_true, y_pred=y_pred)
    R['bac'] = balanced_accuracy_score(y_true=y_true, y_pred=y_pred)
    R['gmean'] = ms.gmean(np.diag(C) / np.sum(C, axis=1))
    R['mcc'] = matthews_corrcoef(y_true=y_true, y_pred=y_pred)
    
    if is_multiclass:
        for avg in ('macro', 'micro'):
            pre, rec, f1, _ = precision_recall_fscore_support(
                y_true=y_true,
                y_pred=y_pred,
                labels=classes,
                average=avg, 
                zero_division=0
            )
            R[f'pre_{avg}'] = pre
            R[f'rec_{avg}'] = rec
            R[f'f1_{avg}'] = f1
    else:
        pre, rec, f1, _ = precision_recall_fscore_support(
            y_true=y_true, y_pred=y_pred, pos_label=c, average='macro', zero_division=0
        )
        R[f'pre_macro'] = pre
        R[f'rec_macro'] = rec
        R[f'f1_macro'] = f1
        
        for c in classes:
            pre, rec, f1, _ = precision_recall_fscore_support(
                y_true=y_true, y_pred=y_pred, pos_label=c, average='binary', zero_division=0
            )
            R[f'pre_{c}'] = pre
            R[f'rec_{c}'] = rec
            R[f'f1_{c}'] = f1

    # Ranking Measure
    if is_multiclass:
        for avg, mc in product(('macro', 'micro'), ('ovr', 'ovo')):
            R[f'roauc_{avg}_{mc}'] = roc_auc_score(
                y_true=y_true, y_score=y_proba,
                average=avg, multi_class=mc, labels=classes
            ) if not is_same_y else np.nan
    else:
        R[f'roauc'] = roc_auc_score(
            y_true=y_true, y_score=y_proba[:, 1], average=None
        ) if not is_same_y else np.nan
        for i, c in enumerate(classes):
            R[f'prauc_{c}'] = average_precision_score(
                y_true=y_true, y_score=y_proba[:, i], pos_label=c, average=None
            ) 
            R[f'prauc_ref_{c}'] = np.sum(y_true == c) / len(y_true)

    # Probability Measure
    R['log_loss'] = log_loss(y_true=y_true, y_pred=y_proba, labels=classes, normalize=True)

    if not is_multiclass:
        R[f'brier_loss'] = brier_score_loss(
            y_true=y_true, y_prob=y_proba[:, 1], pos_label=classes[1]
        )

    return R

# %% [markdown]
# ## Execution

# %%
import os
import pandas as pd
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)


RESULTS_EVAL = []
DIR_EVAL = os.path.join(PATH_INTERMEDIATE, 'eval')

for l in ['attention']:
    dir_l = os.path.join(DIR_EVAL, l)
    if not os.path.exists(dir_l):
        continue
    
    for f in os.listdir(dir_l):
        model, pid = f[:f.index('.pkl')].split('#')
        res = load(os.path.join(dir_l, f))
        X, y = res.X_test, res.y_test
        y_pred = res.estimator.predict(X)
        y_proba = res.estimator.predict_proba(X)
        ev_test = evaluate(
            y_true=y,
            y_pred=y_pred,
            y_proba=y_proba,
            classes=[0, 1]
        )

        X, y = res.X_train, res.y_train
        y_pred = res.estimator.predict(X)
        y_proba = res.estimator.predict_proba(X)
        ev_train = evaluate(
            y_true=y,
            y_pred=y_pred,
            y_proba=y_proba,
            classes=[0, 1]
        )

        RESULTS_EVAL.append({
            'label': l,
            'alg': model,
            'split': pid,
            'n_feature': len(X.columns),
            **{
                f'test_{k}': v for k, v in ev_test.items()
            },
            **{
                f'train_{k}': v for k, v in ev_train.items()
            }
        })
    
RESULTS_EVAL = pd.DataFrame(RESULTS_EVAL)
RESULTS_EVAL
# Out:
#          label    alg split  n_feature  test_inst  test_inst_0  test_inst_1  \
# 0    attention  dummy   P01         84         40           14           26
# 1    attention  dummy   P02         84         51           44            7
# 2    attention  dummy   P03         84         44           33           11
# 3    attention  dummy   P04         84         34           17           17
# 4    attention  dummy   P05         84         51           23           28
# ..         ...    ...   ...        ...        ...          ...          ...
# 147  attention  rf_ns   P76         15         65           45           20
# 148  attention  rf_ns   P77         12         44           24           20
# 149  attention  rf_ns   P78         14         50           39           11
# 150  attention  rf_ns   P79         12         36           13           23
# 151  attention  rf_ns   P80         13         47           14           33
#
#      test_class_ratio  test_true_0_pred_0  test_true_0_pred_1  ...  \
# 0            0.538462                  14                   0  ...
# 1            6.285714                   0                  44  ...
# 2            3.000000                  33                   0  ...
# 3            1.000000                  17                   0  ...
# 4            0.821429                  23                   0  ...
# ..                ...                 ...                 ...  ...
# 147          2.250000                  14                  31  ...
# 148          1.200000                  17                   7  ...
# 149          3.545455                  26                  13  ...
# 150          0.565217                   6                   7  ...
# 151          0.424242                  11                   3  ...
#
#      train_pre_1  train_rec_1  train_f1_1  train_roauc  train_prauc_0  \
# 0       0.000000     0.000000    0.000000     0.500000       0.507158
# 1       0.500306     1.000000    0.666938     0.500000       0.499694
# 2       0.000000     0.000000    0.000000     0.500000       0.501982
# 3       0.000000     0.000000    0.000000     0.500000       0.505321
# 4       0.000000     0.000000    0.000000     0.500000       0.506112
# ..           ...          ...         ...          ...            ...
# 147     0.990786     0.993227    0.992005     0.999691       0.999633
# 148     0.990786     0.993227    0.992005     0.999667       0.999621
# 149     0.990232     0.993264    0.991746     0.999718       0.999658
# 150     0.990769     0.993214    0.991990     0.999705       0.999653
# 151     0.990712     0.993172    0.991940     0.999727       0.999676
#
#      train_prauc_ref_0  train_prauc_1  train_prauc_ref_1  train_log_loss  \
# 0             0.507158       0.492842           0.492842        0.693045
# 1             0.499694       0.500306           0.500306        0.693147
# 2             0.501982       0.498018           0.498018        0.693139
# 3             0.505321       0.494679           0.494679        0.693091
# 4             0.506112       0.493888           0.493888        0.693072
# ..                 ...            ...                ...             ...
# 147           0.501535       0.999623           0.498465        0.210168
# 148           0.504727       0.999598           0.495273        0.210340
# 149           0.501069       0.999652           0.498931        0.210042
# 150           0.506845       0.999633           0.493155        0.210460
# 151           0.508242       0.999651           0.491758        0.210406
#
#      train_brier_loss
# 0            0.249949
# 1            0.250000
# 2            0.249996
# 3            0.249972
# 4            0.249963
# ..                ...
# 147          0.039963
# 148          0.039901
# 149          0.039854
# 150          0.040088
# 151          0.039920
#
# [152 rows x 60 columns]

# %%
import pandas as pd


SUMMARY_EVAL = []

for row in RESULTS_EVAL.groupby(
    ['label', 'alg']
).agg(summary).reset_index().itertuples():
    for k, v in row._asdict().items():
        if type(v) is dict:
            r = dict(
                label=row.label,
                alg=row.alg,
                metric=k,
                **v
            )
            SUMMARY_EVAL.append(r)

SUMMARY_EVAL = pd.DataFrame(SUMMARY_EVAL)    
SUMMARY_EVAL
# Out:
#          label    alg             metric   n  cardinality  \
# 0    attention  dummy              split  76         76.0
# 1    attention  dummy          n_feature  76          NaN
# 2    attention  dummy          test_inst  76          NaN
# 3    attention  dummy        test_inst_0  76          NaN
# 4    attention  dummy        test_inst_1  76          NaN
# ..         ...    ...                ...  ..          ...
# 111  attention  rf_ns  train_prauc_ref_0  76          NaN
# 112  attention  rf_ns      train_prauc_1  76          NaN
# 113  attention  rf_ns  train_prauc_ref_1  76          NaN
# 114  attention  rf_ns     train_log_loss  76          NaN
# 115  attention  rf_ns   train_brier_loss  76          NaN
#
#                                            value_count          sum  \
# 0    P01:1, P50:1, P57:1, P56:1, P55:1, P54:1, P53:...          NaN
# 1                                                  NaN  6384.000000
# 2                                                  NaN  3323.000000
# 3                                                  NaN  1679.000000
# 4                                                  NaN  1644.000000
# ..                                                 ...          ...
# 111                                                NaN    38.400270
# 112                                                NaN    75.965702
# 113                                                NaN    37.599730
# 114                                                NaN    15.944608
# 115                                                NaN     3.018106
#
#           mean         SD        med  \
# 0          NaN        NaN        NaN
# 1    84.000000   0.000000  84.000000
# 2    43.723684  19.362919  43.500000
# 3    22.092105  13.619768  18.500000
# 4    21.631579  13.787765  20.000000
# ..         ...        ...        ...
# 111   0.505267   0.002972   0.505371
# 112   0.999549   0.000098   0.999566
# 113   0.494733   0.002972   0.494629
# 114   0.209797   0.001095   0.209916
# 115   0.039712   0.000377   0.039784
#
#                                           range  \
# 0                                           NaN
# 1                                      (84, 84)
# 2                                       (3, 83)
# 3                                       (1, 78)
# 4                                       (1, 64)
# ..                                          ...
# 111    (0.4941358024691358, 0.5142944973870274)
# 112    (0.9992372711010233, 0.9997165417176543)
# 113   (0.48570550261297263, 0.5058641975308642)
# 114   (0.20685558377282462, 0.2122228506408036)
# 115  (0.03878640388346345, 0.04040188665097325)
#
#                                           conf.  nan_count
# 0                                           NaN        NaN
# 1                                    (nan, nan)        0.0
# 2        (39.29906768359284, 48.14830073745979)        0.0
# 3       (18.97985503997637, 25.204355486339416)        0.0
# 4        (18.480939742255043, 24.7822181524818)        0.0
# ..                                          ...        ...
# 111     (0.504587560184556, 0.5059458629707974)        0.0
# 112    (0.9995263866253213, 0.9995710303702311)        0.0
# 113     (0.4940541370292026, 0.495412439815444)        0.0
# 114   (0.2095472460042336, 0.21004770199200676)        0.0
# 115  (0.03962573771653817, 0.03979810122099736)        0.0
#
# [116 rows x 13 columns]

# %% [markdown]
# Below shows metrics of our interest only.

# %%
SUB_SUMMARY_EVAL = SUMMARY_EVAL.loc[
    lambda x: x['metric'].isin(
        ['n_feature', 'train_class_ratio', 'train_inst_0', 'train_inst_1', 'test_inst_0', 'test_inst_1', 'test_acc', 'test_f1_0' ,'test_f1_1', 'test_f1_macro', 'train_f1_0' ,'train_f1_1', 'train_f1_macro',]
    )
].round(3).assign(
    mean_sd=lambda x: x['mean'].astype(str).str.cat(' (' + x['SD'].astype(str) + ')', sep='')
).pivot(
    index=['label', 'alg'], columns=['metric'], values=['mean_sd']
)
SUB_SUMMARY_EVAL
# Out:
#                         mean_sd                                               \
# metric                n_feature       test_acc      test_f1_0      test_f1_1
# label     alg
# attention dummy      84.0 (0.0)  0.479 (0.194)   0.617 (0.21)  0.006 (0.032)
#           rf_ns  14.197 (1.307)  0.534 (0.093)  0.527 (0.155)  0.476 (0.162)
#
#                                                                  \
# metric           test_f1_macro     test_inst_0      test_inst_1
# label     alg
# attention dummy  0.311 (0.098)  22.092 (13.62)  21.632 (13.788)
#           rf_ns   0.501 (0.09)  22.092 (13.62)  21.632 (13.788)
#
#                                                                  \
# metric          train_class_ratio     train_f1_0     train_f1_1
# label     alg
# attention dummy     1.021 (0.012)  0.645 (0.132)  0.026 (0.131)
#           rf_ns     1.021 (0.012)    0.992 (0.0)    0.992 (0.0)
#
#
# metric          train_f1_macro      train_inst_0       train_inst_1
# label     alg
# attention dummy  0.336 (0.001)  1656.908 (13.62)  1622.368 (13.788)
#           rf_ns    0.992 (0.0)  1656.908 (13.62)  1622.368 (13.788)

# %% [markdown]
# # Feature Importances

# %% [markdown]
# ## Implementation

# %%
from typing import Union, Optional


def feature_importance(
    estimator
):
    if not hasattr(estimator, 'feature_names_in_') or not hasattr(estimator, 'feature_importances_'):
        return None
    
    names = estimator.feature_names_in_
    importances = estimator.feature_importances_
    
    return names, importances

# %% [markdown]
# ## Execution

# %%
import os
import pandas as pd
from collections import defaultdict


IMPORTANCE_EVAL = defaultdict(list)
DIR_EVAL = os.path.join(PATH_INTERMEDIATE, 'eval')

for l in ['attention']:
    dir_l = os.path.join(DIR_EVAL, l)
    if not os.path.exists(dir_l):
        continue
    
    for f in os.listdir(dir_l):
        res = load(os.path.join(dir_l, f))

        f_norm = f[:f.index('.pkl')]
        alg = f_norm[:f.rindex('#')]
        
        feat_imp = feature_importance(res.estimator)
        if not feat_imp:
            continue
            
        names, importance = feat_imp
        new_names = []
        for n in names:
            for c in res.categories:
                n = n.replace(f'{c}_', f'{c}=')
            new_names.append(n)
        
        d = pd.DataFrame(
            importance.reshape(1, -1),
            columns=new_names
        )
        IMPORTANCE_EVAL[(l, alg)].append(d)
        

IMPORTANCE_SUMMARY = []

for (l, alg), v in IMPORTANCE_EVAL.items():
    new_v = pd.concat(
        v, axis=0
    ).fillna(0.0).mean().reset_index().set_axis(
        ['feature', 'importance'], axis=1
    ).assign(
        label=l,
        alg=alg
    )
    IMPORTANCE_SUMMARY.append(new_v)
    
IMPORTANCE_SUMMARY = pd.concat(IMPORTANCE_SUMMARY, axis=0, ignore_index=True)

# %% [markdown]
# ### Plot

# %%
# %%R -i IMPORTANCE_SUMMARY -w 26 -h 16 -u cm
#
# library(ggplot2)
# library(dplyr)
# library(stringr)
# library(patchwork)
#
# data <- IMPORTANCE_SUMMARY %>% filter(label == 'attention')
#
# p_label <- ggplot() + geom_text(
#     aes(x = .5, y = .5),
#     label = 'Attention',
#     family = 'ssp',
#     fontface = 'bold',
#     size = 4
# ) + theme_void()
#
# p_rf <- ggplot(
#     data %>% filter(alg == 'rf_os') %>% top_n(n = 10, wt = importance),
#     aes(x = reorder(feature, -importance), y = importance)
# ) + geom_col() +
#     THEME_DEFAULT + theme(
#         axis.text.x = element_text(angle = 90, size = 10, hjust = 1, vjust = .5),
#         axis.title.x = element_blank(),
#         axis.title.y = element_blank()
#     ) + labs(subtitle = 'Random Forest')
#
# p_xgb <- ggplot(
#     data %>% filter(alg == 'xgb_os') %>% top_n(n = 10, wt = importance),
#     aes(x = reorder(feature, -importance), y = importance)
# ) + geom_col() +
#     THEME_DEFAULT + theme(
#         axis.text.x = element_text(angle = 90, size = 10, hjust = 1, vjust = .5),
#         axis.title.x = element_blank(),
#         axis.title.y = element_blank()
#     ) + labs(subtitle = 'XGBoost')
#
# p <- p_label / (p_rf | p_xgb) + plot_layout(heights = c(1.1, 10))
#
# ggsave('./fig/imp_attention.pdf', plot = p, width = 26, height = 16, unit = 'cm', device = cairo_pdf)
# print(p)
# Out:
# UsageError: Cell magic `%%R` not found.
